# %% [markdown]
# # NLE Assignment 2: Distributional Semantics
#
# In this assignment, you will be investigating the *distributional hypothesis*: **words which appear in similar contexts tend to have similar meanings**.
#
# For assessment, you are expected to complete and submit this notebook file. When answers require code, you may import and use library functions (unless explicitly told otherwise). All of your own code should be included in the notebook rather than imported from elsewhere. Written answers should also be included in the notebook. You should insert as many extra cells as you want and change the type between code and markdown as appropriate.
#
# In order to avoid misconduct, you should not talk about the assignment questions with your peers. If you are not sure what a question is asking you to do or have any other questions, please ask me or one of the Teaching Assistants.
#
# Marking guidelines are provided as a separate document.
#
# The first few cells contain code to set-up the assignment and bring in some data. In order to provide unique datasets for analysis by different students, you must enter your candidate number in the following cell. Otherwise do not change the code in these cells.

# %%
candidateno=198397 #this MUST be updated to your candidate number so that you get a unique data sample

# %%
#set up drives for resources.  Change the path as necessary

from google.colab import drive
#mount google drive
drive.mount('/content/drive/')
import sys
sys.path.append('/content/drive/My Drive/NLE Notebooks/resources/')
# Out:
# Mounted at /content/drive/

# %%
#do not change the code in this cell
#preliminary imports

import re
import random
import math
import pandas as pd
import matplotlib.pyplot as plt
from itertools import zip_longest

import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('wordnet_ic')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.corpus import wordnet as wn
from nltk.corpus import wordnet_ic as wn_ic
brown_ic = wn_ic.ic("ic-brown.dat")


from sussex_nltk.corpus_readers import ReutersCorpusReader
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet_ic.zip.
# Sussex NLTK root directory is /content/drive/My Drive/NLE Notebooks/resources

# %% [markdown]
# We are going to be using the Reuters corpus of financial documents for this assignment.  When you run the following cell you should see that it contains 1,113,359 sentences.

# %%
#do not change the code in this cell
rcr = ReutersCorpusReader().finance()
rcr.enumerate_sents()
# Out:
# 1113359

# %% [markdown]
# The following cell will take 2-5 minutes to run.  It will generate a unique-to-you sample of 200,000 sentences.  These sentences are tokenised and normalised for case and number for you.

# %%
#do not change the code in this cell
def normalise(tokenlist):
    tokenlist=[token.lower() for token in tokenlist]
    tokenlist=["NUM" if token.isdigit() else token for token in tokenlist]
    tokenlist=["Nth" if (token.endswith(("nd","st","th")) and token[:-2].isdigit()) else token for token in tokenlist]
    tokenlist=["NUM" if re.search("^[+-]?[0-9]+\.[0-9]",token) else token for token in tokenlist]
    return tokenlist

random.seed(candidateno)  
samplesize=2000
iterations =100
sentences=[]
for i in range(0,iterations):
    sentences+=[normalise(sent) for sent in rcr.sample_sents(samplesize=samplesize)]
    print("Completed {}%".format(i))
print("Completed 100%")
# Out:
# Completed 0%
# Completed 1%
# Completed 2%
# Completed 3%
# Completed 4%
# Completed 5%
# Completed 6%
# Completed 7%
# Completed 8%
# Completed 9%
# Completed 10%
# Completed 11%
# Completed 12%
# Completed 13%
# Completed 14%
# Completed 15%
# Completed 16%
# Completed 17%
# Completed 18%
# Completed 19%
# Completed 20%
# Completed 21%
# Completed 22%
# Completed 23%
# Completed 24%
# Completed 25%
# Completed 26%
# Completed 27%
# Completed 28%
# Completed 29%
# Completed 30%
# Completed 31%
# Completed 32%
# Completed 33%
# Completed 34%
# Completed 35%
# Completed 36%
# Completed 37%
# Completed 38%
# Completed 39%
# Completed 40%
# Completed 41%
# Completed 42%
# Completed 43%
# Completed 44%
# Completed 45%
# Completed 46%
# Completed 47%
# Completed 48%
# Completed 49%
# Completed 50%
# Completed 51%
# Completed 52%
# Completed 53%
# Completed 54%
# Completed 55%
# Completed 56%
# Completed 57%
# Completed 58%
# Completed 59%
# Completed 60%
# Completed 61%
# Completed 62%
# Completed 63%
# Completed 64%
# Completed 65%
# Completed 66%
# Completed 67%
# Completed 68%
# Completed 69%
# Completed 70%
# Completed 71%
# Completed 72%
# Completed 73%
# Completed 74%
# Completed 75%
# Completed 76%
# Completed 77%
# Completed 78%
# Completed 79%
# Completed 80%
# Completed 81%
# Completed 82%
# Completed 83%
# Completed 84%
# Completed 85%
# Completed 86%
# Completed 87%
# Completed 88%
# Completed 89%
# Completed 90%
# Completed 91%
# Completed 92%
# Completed 93%
# Completed 94%
# Completed 95%
# Completed 96%
# Completed 97%
# Completed 98%
# Completed 99%
# Completed 100%

# %% [markdown]
# `generate_features()` will used in the first part of the assignment.

# %%
#do not change the code in this cell
def generate_features(sentences,window=1):
    mydict={}
    for sentence in sentences:
        for i,token in enumerate(sentence):
            current=mydict.get(token,{})
            features=sentence[max(0,i-window):i]+sentence[i+1:i+window+1]
            for feature in features:
                current[feature]=current.get(feature,0)+1
            mydict[token]=current
    return mydict

# %% [markdown]
# 1) Run `generate_features(sentences[:5])`. With reference to the code and the specific examples, explain how the output was generated [10 marks]

# %%
generate_features(sentences[:5])
# Out:
# {'$': {'in': 1, 'mln': 1},
#  '&': {'edwards': 1, 'sons': 1},
#  "''": {',': 1, 'analyst': 1},
#  '(': {'account': 1, 'in': 1, 'may': 1, 'postipankki': 1},
#  ')': {'NUM': 2, 'mln': 1},
#  ',': {"''": 1, 'inc': 1, 'realistic': 1, 'sons': 1},
#  '.': {'gmt': 1, 'inc': 1, 'reuters': 1},
#  '=': {'postipankki': 1, 'psp': 1},
#  'NUM': {')': 2, 'NUM': 4, 'around': 1, 'gmt': 1, 'may': 1},
#  '``': {'the': 1},
#  'a.g.': {'edwards': 1},
#  'account': {'(': 1, 'current': 1},
#  'analyst': {"''": 1, 'zuna': 1},
#  'are': {'not': 1, 'targets': 1},
#  'around': {'NUM': 1, 'vote': 1},
#  'baring': {'ing': 1, 'securities': 1},
#  'current': {'account': 1},
#  'edwards': {'&': 1, 'a.g.': 1},
#  'gmt': {'.': 1, 'NUM': 1},
#  'in': {'$': 1, '(': 1},
#  'inc': {',': 1, '.': 1},
#  'ing': {'baring': 1, 'of': 1},
#  'mansoor': {'of': 1, 'zuna': 1},
#  'may': {'(': 1, 'NUM': 1},
#  'mln': {'$': 1, ')': 1},
#  'not': {'are': 1, 'realistic': 1},
#  'of': {'ing': 1, 'mansoor': 1},
#  'postipankki': {'(': 1, '=': 1},
#  'psp': {'=': 1},
#  'realistic': {',': 1, 'not': 1},
#  'reuters': {'.': 1, 'told': 1},
#  'securities': {'baring': 1, 'told': 1},
#  'shift': {'third': 1, 'will': 1},
#  'sons': {'&': 1, ',': 1},
#  'targets': {'are': 1, 'the': 1},
#  'the': {'``': 1, 'targets': 1, 'third': 1},
#  'third': {'shift': 1, 'the': 1},
#  'told': {'reuters': 1, 'securities': 1},
#  'vote': {'around': 1, 'will': 1},
#  'will': {'shift': 1, 'vote': 1},
#  'zuna': {'analyst': 1, 'mansoor': 1}}

# %% [markdown]
# > The function generate_features is a function which takes in an input 'sentences' and a second input 'window'. The 'sentences' is a list of sentences being [:5] meaning it takes up to 5 sentences  and the 'window' is by default 1 which is an area around a target word. The window  takes the default value of window (which equals one) to the set value of 5 i.e [1:5] being the first five sentences in the list. These sentences are then broken down into tokens and iterated through a for loop creating further windows specifically either side of each token. For example, [max(0,i-window):i]+sentence[i+1:i+window+1] takes a single word from either side, because window is the value i (being the position) so it goes back a position and infront a position of the target word. This then gives produces a word and a window of the words either side of it and counts the co-occurences of words. For example in the result above ')': {'NUM': 2, 'mln': 1} states that ')' co-occurs with 'NUM' twice and mln once. NUM can be an number and brackets are often used with mathematic equations so it is likely thats why this combination occurs most. This then outputs into a dictionary and we can see every word of the sentences with a list of words that occur with them and the amount of times they co-occur.

# %% [markdown]
# 2) Write code and **find** the 1000 most frequently occurring words that
# * are in your sample; AND
# * have at least one noun sense according to WordNet [10 marks]

# %%
import operator
stop = stopwords.words('english')
dictnouns = {}
def getdictnouns(sentences):
  for sentence in sentences: #iterate through sentences
    for words in sentence: #iterates through words 
      if len(wn.synsets(sentence[0], wn.NOUN)) >0: #checks for atleast one noun sense
        if words in dictnouns:
          dictnouns[words] += 1 #adds to word frequency
        else:
          dictnouns.update({words:1}) #adds to dictionary and initialises frequency
getdictnouns(sentences)
dictnouns

#below is all the normalisation to remove tokens with no content suchas, number, symbols and stopwords
dictnouns_stopremoval = {k: v for k,v in dictnouns.items() if k not in stop and k.isalpha()and k != "NUM"}
sortednouns = dict(sorted(dictnouns_stopremoval.items(), key=operator.itemgetter(1), reverse=True))
sortednouns
# Out:
# {'said': 12706,
#  'percent': 8142,
#  'would': 4296,
#  'million': 4046,
#  'pct': 3989,
#  'year': 3983,
#  'bank': 3876,
#  'may': 3728,
#  'billion': 3393,
#  'government': 3120,
#  'trade': 2760,
#  'tax': 2591,
#  'economic': 2314,
#  'last': 2235,
#  'rate': 2164,
#  'budget': 2156,
#  'new': 2130,
#  'june': 2122,
#  'minister': 2045,
#  'growth': 1995,
#  'first': 1936,
#  'april': 1920,
#  'also': 1789,
#  'price': 1765,
#  'union': 1752,
#  'central': 1739,
#  'balance': 1678,
#  'bonds': 1671,
#  'state': 1667,
#  'inflation': 1662,
#  'finance': 1603,
#  'total': 1592,
#  'bln': 1550,
#  'foreign': 1527,
#  'march': 1496,
#  'gdp': 1477,
#  'prices': 1449,
#  'expected': 1442,
#  'wednesday': 1417,
#  'index': 1410,
#  'deficit': 1397,
#  'tuesday': 1391,
#  'could': 1378,
#  'currency': 1357,
#  'due': 1354,
#  'economy': 1350,
#  'thursday': 1346,
#  'week': 1344,
#  'july': 1344,
#  'market': 1319,
#  'rates': 1275,
#  'change': 1271,
#  'interest': 1263,
#  'exports': 1234,
#  'two': 1233,
#  'european': 1212,
#  'one': 1181,
#  'officials': 1158,
#  'monday': 1143,
#  'monetary': 1142,
#  'friday': 1136,
#  'current': 1119,
#  'years': 1091,
#  'rise': 1082,
#  'official': 1080,
#  'month': 1079,
#  'debt': 1065,
#  'coupon': 1048,
#  'delivery': 1029,
#  'maturity': 1018,
#  'call': 1018,
#  'rose': 1001,
#  'sales': 995,
#  'time': 978,
#  'series': 978,
#  'strike': 976,
#  'imports': 971,
#  'capital': 968,
#  'president': 967,
#  'apr': 966,
#  'analysts': 963,
#  'investment': 959,
#  'issue': 958,
#  'domestic': 954,
#  'next': 953,
#  'public': 952,
#  'unemployment': 947,
#  'three': 931,
#  'amount': 929,
#  'japan': 910,
#  'china': 887,
#  'country': 868,
#  'told': 855,
#  'sale': 854,
#  'consumer': 851,
#  'period': 850,
#  'cut': 848,
#  'months': 848,
#  'money': 847,
#  'reserves': 845,
#  'sector': 841,
#  'eu': 836,
#  'p': 834,
#  'moody': 829,
#  'quarter': 818,
#  'workers': 817,
#  'international': 816,
#  'aaa': 812,
#  'date': 812,
#  'financial': 805,
#  'end': 802,
#  'national': 801,
#  'germany': 797,
#  'policy': 793,
#  'inc': 787,
#  'emu': 786,
#  'business': 784,
#  'economists': 781,
#  'talks': 770,
#  'german': 764,
#  'yield': 763,
#  'prime': 756,
#  'data': 755,
#  'figures': 753,
#  'bond': 747,
#  'countries': 746,
#  'company': 745,
#  'since': 743,
#  'markets': 738,
#  'meeting': 736,
#  'general': 735,
#  'spending': 735,
#  'labour': 732,
#  'house': 731,
#  'states': 724,
#  'south': 709,
#  'treasury': 709,
#  'mln': 703,
#  'increase': 694,
#  'forecast': 692,
#  'plan': 686,
#  'industry': 683,
#  'exchange': 678,
#  'plans': 678,
#  'ministry': 677,
#  'banks': 677,
#  'world': 668,
#  'bill': 660,
#  'united': 655,
#  'output': 649,
#  'revenue': 645,
#  'added': 636,
#  'companies': 635,
#  'oil': 634,
#  'credit': 633,
#  'france': 627,
#  'gross': 626,
#  'clinton': 624,
#  'account': 620,
#  'say': 620,
#  'deal': 612,
#  'feb': 611,
#  'average': 608,
#  'set': 605,
#  'school': 602,
#  'city': 600,
#  'annual': 598,
#  'private': 590,
#  'services': 586,
#  'mar': 583,
#  'gold': 583,
#  'net': 583,
#  'cpi': 580,
#  'pay': 578,
#  'report': 576,
#  'jobs': 575,
#  'earlier': 574,
#  'county': 574,
#  'latest': 572,
#  'agreement': 572,
#  'still': 570,
#  'note': 568,
#  'fiscal': 565,
#  'orders': 563,
#  'says': 554,
#  'key': 553,
#  'five': 552,
#  'statement': 551,
#  'fund': 550,
#  'surplus': 545,
#  'jul': 541,
#  'dollar': 537,
#  'europe': 536,
#  'goods': 535,
#  'industrial': 534,
#  'aid': 530,
#  'italy': 530,
#  'single': 529,
#  'british': 523,
#  'fell': 522,
#  'previous': 522,
#  'federal': 521,
#  'group': 520,
#  'made': 516,
#  'ago': 514,
#  'compared': 513,
#  'high': 513,
#  'recent': 512,
#  'seen': 510,
#  'product': 509,
#  'work': 508,
#  'statistics': 508,
#  'indicators': 507,
#  'monthly': 506,
#  'higher': 505,
#  'french': 504,
#  'meet': 502,
#  'issuer': 501,
#  'retail': 496,
#  'likely': 495,
#  'system': 492,
#  'jun': 491,
#  'local': 490,
#  'features': 488,
#  'lower': 486,
#  'people': 486,
#  'fall': 483,
#  'leaders': 481,
#  'real': 479,
#  'second': 479,
#  'district': 476,
#  'around': 476,
#  'reform': 475,
#  'news': 471,
#  'help': 469,
#  'following': 462,
#  'demand': 462,
#  'service': 462,
#  'russia': 462,
#  'final': 461,
#  'brazil': 461,
#  'february': 456,
#  'imf': 454,
#  'per': 451,
#  'britain': 450,
#  'cuts': 449,
#  'north': 448,
#  'firms': 445,
#  'showed': 445,
#  'level': 444,
#  'back': 444,
#  'take': 443,
#  'food': 442,
#  'planned': 442,
#  'reuters': 437,
#  'thailand': 434,
#  'major': 433,
#  'india': 433,
#  'investors': 429,
#  'four': 429,
#  'make': 427,
#  'committee': 425,
#  'strong': 424,
#  'reserve': 421,
#  'members': 421,
#  'production': 420,
#  'parliament': 419,
#  'six': 418,
#  'none': 417,
#  'development': 414,
#  'saying': 412,
#  'us': 411,
#  'much': 407,
#  'manufacturing': 406,
#  'start': 404,
#  'spokesman': 398,
#  'including': 398,
#  'aug': 397,
#  'export': 396,
#  'income': 395,
#  'already': 393,
#  'reforms': 393,
#  'st': 392,
#  'reported': 389,
#  'board': 389,
#  'canada': 387,
#  'notes': 386,
#  'cost': 386,
#  'enhancements': 385,
#  'funds': 385,
#  'must': 384,
#  'agreed': 383,
#  'day': 383,
#  'employment': 381,
#  'part': 380,
#  'despite': 379,
#  'well': 376,
#  'measures': 376,
#  'number': 375,
#  'firm': 373,
#  'half': 371,
#  'january': 369,
#  'many': 369,
#  'party': 368,
#  'housing': 367,
#  'kohl': 366,
#  'department': 363,
#  'taxes': 363,
#  'office': 360,
#  'securities': 357,
#  'social': 356,
#  'authority': 356,
#  'even': 354,
#  'supply': 353,
#  'go': 353,
#  'australia': 351,
#  'move': 350,
#  'survey': 349,
#  'wage': 349,
#  'see': 348,
#  'basis': 348,
#  'uk': 347,
#  'points': 347,
#  'called': 347,
#  'obligation': 346,
#  'decision': 345,
#  'stat': 345,
#  'na': 345,
#  'korea': 345,
#  'low': 344,
#  'unions': 344,
#  'changes': 344,
#  'bundesbank': 343,
#  'target': 342,
#  'support': 342,
#  'conference': 341,
#  'mexico': 340,
#  'august': 339,
#  'political': 339,
#  'congress': 339,
#  'fed': 338,
#  'list': 336,
#  'japanese': 335,
#  'announced': 334,
#  'payments': 334,
#  'past': 334,
#  'agency': 334,
#  'co': 333,
#  'forecasts': 333,
#  'days': 332,
#  'brown': 331,
#  'loans': 331,
#  'senior': 331,
#  'summit': 330,
#  'nations': 327,
#  'australian': 323,
#  'economist': 322,
#  'deposits': 322,
#  'marks': 322,
#  'sr': 322,
#  'chief': 322,
#  'governor': 321,
#  'czech': 321,
#  'qual': 319,
#  'revenues': 319,
#  'senate': 318,
#  'early': 318,
#  'ahead': 317,
#  'taiwan': 316,
#  'former': 315,
#  'jan': 315,
#  'indicator': 314,
#  'euro': 314,
#  'way': 314,
#  'conc': 314,
#  'mgr': 313,
#  'whether': 312,
#  'commission': 312,
#  'far': 312,
#  'according': 311,
#  'continue': 310,
#  'wages': 307,
#  'free': 306,
#  'secretary': 305,
#  'improvement': 305,
#  'issues': 305,
#  'percentage': 305,
#  'gmt': 304,
#  'health': 304,
#  'opposition': 304,
#  'privatisation': 303,
#  'raise': 302,
#  'ministers': 302,
#  'washington': 301,
#  'increased': 301,
#  'put': 296,
#  'pricing': 295,
#  'released': 294,
#  'costs': 294,
#  'russian': 293,
#  'construction': 293,
#  'another': 292,
#  'conditions': 291,
#  'issued': 291,
#  'future': 291,
#  'seven': 291,
#  'morgan': 291,
#  'stock': 291,
#  'later': 290,
#  'building': 289,
#  'kong': 288,
#  'power': 288,
#  'rating': 288,
#  'hong': 287,
#  'law': 287,
#  'smith': 287,
#  'base': 285,
#  'need': 283,
#  'spain': 283,
#  'approved': 283,
#  'yen': 282,
#  'bonn': 282,
#  'election': 281,
#  'less': 281,
#  'programme': 281,
#  'thai': 280,
#  'labor': 278,
#  'chancellor': 278,
#  'terms': 277,
#  'trillion': 276,
#  'commercial': 275,
#  'sunday': 273,
#  'stability': 273,
#  'boost': 273,
#  'criteria': 273,
#  'approx': 272,
#  'sources': 272,
#  'use': 271,
#  'value': 270,
#  'proposed': 268,
#  'import': 268,
#  'late': 268,
#  'possible': 266,
#  'region': 265,
#  'loan': 264,
#  'given': 264,
#  'good': 264,
#  'preliminary': 264,
#  'give': 263,
#  'africa': 263,
#  'white': 260,
#  'get': 260,
#  'deputy': 259,
#  'overall': 259,
#  'levels': 259,
#  'leader': 259,
#  'council': 258,
#  'without': 258,
#  'avg': 257,
#  'based': 257,
#  'problems': 257,
#  'pact': 257,
#  'action': 256,
#  'long': 256,
#  'notice': 255,
#  'coalition': 254,
#  'hit': 253,
#  'details': 252,
#  'cash': 252,
#  'saturday': 252,
#  'chairman': 251,
#  'tonnes': 251,
#  'needed': 250,
#  'full': 249,
#  'security': 249,
#  'main': 249,
#  'waigel': 249,
#  'job': 249,
#  'within': 249,
#  'products': 249,
#  'come': 248,
#  'mark': 247,
#  'tic': 246,
#  'barney': 246,
#  'poland': 244,
#  'grew': 244,
#  'vote': 244,
#  'adjusted': 244,
#  'pressure': 243,
#  'used': 243,
#  'leading': 243,
#  'producer': 242,
#  'baht': 242,
#  'join': 242,
#  'education': 241,
#  'top': 241,
#  'iraq': 241,
#  'trading': 239,
#  'negotiations': 239,
#  'banking': 239,
#  'rising': 239,
#  'member': 239,
#  'savings': 239,
#  'source': 238,
#  'confidence': 238,
#  'might': 238,
#  'american': 238,
#  'among': 238,
#  'subject': 237,
#  'sees': 237,
#  'east': 235,
#  'held': 235,
#  'treaty': 235,
#  'hungary': 235,
#  'little': 234,
#  'reached': 234,
#  'september': 233,
#  'israel': 232,
#  'energy': 232,
#  'point': 232,
#  'employees': 231,
#  'available': 230,
#  'minimum': 229,
#  'close': 229,
#  'poll': 228,
#  'association': 228,
#  'nic': 227,
#  'show': 227,
#  'dollars': 227,
#  'term': 227,
#  'largest': 226,
#  'ba': 225,
#  'institute': 225,
#  'legislation': 225,
#  'special': 224,
#  'keep': 224,
#  'result': 224,
#  'par': 224,
#  'revised': 224,
#  'staff': 223,
#  'weeks': 223,
#  'reduce': 223,
#  'open': 223,
#  'newspaper': 222,
#  'like': 222,
#  'working': 222,
#  'comment': 222,
#  'administration': 222,
#  'poor': 222,
#  'proposal': 221,
#  'worth': 221,
#  'sell': 221,
#  'allow': 220,
#  'projects': 220,
#  'transport': 219,
#  'maastricht': 219,
#  'york': 219,
#  'shares': 218,
#  'large': 218,
#  'rises': 218,
#  'c': 218,
#  'several': 217,
#  'management': 217,
#  'force': 217,
#  'daily': 217,
#  'range': 216,
#  'least': 216,
#  'raised': 216,
#  'reporters': 215,
#  'order': 215,
#  'london': 214,
#  'water': 213,
#  'figure': 213,
#  'clear': 212,
#  'bulgaria': 212,
#  'package': 211,
#  'yr': 211,
#  'de': 211,
#  'declined': 211,
#  'estimated': 211,
#  'small': 211,
#  'indonesia': 211,
#  'big': 210,
#  'air': 210,
#  'paper': 209,
#  'african': 209,
#  'policies': 209,
#  'expect': 208,
#  'sep': 207,
#  'initial': 205,
#  'bid': 205,
#  'property': 205,
#  'impact': 205,
#  'trend': 205,
#  'project': 205,
#  'delay': 204,
#  'operations': 203,
#  'plant': 203,
#  'yet': 203,
#  'pounds': 202,
#  'expectations': 201,
#  'port': 201,
#  'share': 201,
#  'dealers': 201,
#  'democrats': 200,
#  'eight': 200,
#  'cabinet': 199,
#  'singapore': 199,
#  'unchanged': 198,
#  'court': 198,
#  'gm': 198,
#  'external': 198,
#  'record': 197,
#  'dispute': 197,
#  'met': 197,
#  'reach': 196,
#  'launch': 196,
#  'rules': 195,
#  'remain': 195,
#  'italian': 195,
#  'control': 195,
#  'wholesale': 195,
#  'crisis': 194,
#  'hold': 194,
#  'decline': 193,
#  'offer': 192,
#  'line': 192,
#  'efforts': 191,
#  'nearly': 191,
#  'third': 189,
#  'ended': 188,
#  'nation': 187,
#  'december': 187,
#  'romania': 187,
#  'although': 186,
#  'corporate': 186,
#  'jobless': 186,
#  'urged': 186,
#  'wants': 186,
#  'currently': 186,
#  'gave': 185,
#  'earnings': 185,
#  'vs': 185,
#  'polish': 185,
#  'contract': 184,
#  'director': 184,
#  'consumption': 183,
#  'majority': 183,
#  'investments': 183,
#  'population': 182,
#  'taken': 182,
#  'head': 182,
#  'ups': 182,
#  'republican': 181,
#  'west': 181,
#  'ruling': 181,
#  'think': 180,
#  'discuss': 180,
#  'drop': 180,
#  'growing': 180,
#  'recovery': 180,
#  'assets': 179,
#  'want': 179,
#  'bankers': 179,
#  'wheat': 179,
#  'malaysia': 178,
#  'seasonally': 178,
#  'asian': 177,
#  'argentina': 177,
#  'california': 177,
#  'war': 177,
#  'warned': 177,
#  'global': 177,
#  'goldman': 176,
#  'jospin': 176,
#  'rand': 176,
#  'authorities': 176,
#  'portugal': 176,
#  'continued': 176,
#  'noted': 175,
#  'western': 175,
#  'however': 175,
#  'progress': 175,
#  'soon': 174,
#  'indian': 174,
#  'america': 174,
#  'effect': 173,
#  'john': 173,
#  'lead': 173,
#  'saw': 173,
#  'october': 173,
#  'remained': 173,
#  'auction': 172,
#  'stocks': 172,
#  'commerce': 172,
#  'fitch': 171,
#  'view': 171,
#  'provide': 171,
#  'making': 171,
#  'consensus': 171,
#  'sachs': 170,
#  'research': 170,
#  'pension': 170,
#  'case': 170,
#  'quoted': 170,
#  'hours': 170,
#  'regional': 169,
#  'pakistan': 169,
#  'weekly': 169,
#  'membership': 169,
#  'led': 169,
#  'police': 168,
#  'place': 168,
#  'george': 168,
#  'received': 168,
#  'lending': 168,
#  'scheduled': 167,
#  'left': 167,
#  'visit': 167,
#  'rights': 166,
#  'gap': 166,
#  'yields': 166,
#  'areas': 165,
#  'failed': 165,
#  'home': 164,
#  'unlikely': 164,
#  'asia': 163,
#  'liquidity': 163,
#  'stable': 163,
#  'focus': 162,
#  'sanctions': 162,
#  'paid': 162,
#  'profits': 161,
#  'groups': 161,
#  'entry': 161,
#  'eastern': 161,
#  'began': 161,
#  'gains': 160,
#  'republic': 160,
#  'outlook': 160,
#  'signed': 160,
#  'funding': 160,
#  'quarterly': 159,
#  'traders': 159,
#  'award': 159,
#  'chinese': 159,
#  'increases': 159,
#  'bear': 159,
#  'slovak': 159,
#  'wanted': 158,
#  'n': 158,
#  'benefits': 158,
#  'position': 158,
#  'include': 158,
#  'flights': 157,
#  'aimed': 157,
#  'present': 157,
#  'bills': 157,
#  'slow': 156,
#  'hard': 156,
#  'corp': 156,
#  'theo': 156,
#  'seek': 156,
#  'return': 156,
#  'independent': 155,
#  'street': 155,
#  'debate': 155,
#  'speaking': 155,
#  'table': 155,
#  'reports': 154,
#  'dutch': 154,
#  'partners': 154,
#  'finland': 154,
#  'needs': 154,
#  'lawmakers': 154,
#  'sweden': 154,
#  'wto': 154,
#  'taking': 153,
#  'sign': 153,
#  'protest': 153,
#  'eurobond': 153,
#  'coming': 153,
#  'measure': 153,
#  'updated': 153,
#  'interview': 152,
#  'businesses': 152,
#  'texas': 152,
#  'industries': 152,
#  'republicans': 152,
#  'process': 151,
#  'crowns': 151,
#  'expansion': 151,
#  'important': 151,
#  'panel': 150,
#  'concern': 150,
#  'borrowing': 150,
#  'dean': 150,
#  'deficits': 150,
#  'planning': 149,
#  'facilities': 149,
#  'asked': 149,
#  'community': 149,
#  'recently': 149,
#  'positive': 149,
#  'expenditure': 149,
#  'grow': 149,
#  'billions': 148,
#  'iran': 148,
#  'volume': 148,
#  'direct': 148,
#  'sectors': 148,
#  'activity': 147,
#  'dec': 147,
#  'conservative': 147,
#  'sterling': 147,
#  'currencies': 146,
#  'ratio': 146,
#  'witter': 146,
#  'plc': 145,
#  'risk': 145,
#  'agriculture': 145,
#  'military': 145,
#  'short': 145,
#  'financing': 145,
#  'allowed': 144,
#  'dropped': 144,
#  'right': 144,
#  'democratic': 144,
#  'press': 144,
#  'parliamentary': 143,
#  'slightly': 143,
#  'offered': 142,
#  'prev': 142,
#  'took': 142,
#  'stanley': 142,
#  'become': 142,
#  'employers': 142,
#  'rather': 142,
#  'ltd': 141,
#  'better': 141,
#  'vietnam': 141,
#  'welfare': 141,
#  'insurance': 140,
#  'pace': 140,
#  'mainly': 140,
#  'ukraine': 140,
#  'swiss': 140,
#  'lowest': 139,
#  'published': 139,
#  'towards': 139,
#  'speech': 139,
#  'face': 139,
#  'looking': 139,
#  'alternative': 139,
#  'fbs': 139,
#  'almost': 139,
#  'seeking': 139,
#  'november': 139,
#  'results': 138,
#  'going': 138,
#  'tourism': 138,
#  'came': 138,
#  'car': 138,
#  'municipal': 138,
#  'site': 138,
#  'spread': 137,
#  'biggest': 137,
#  'helmut': 137,
#  'spokeswoman': 137,
#  'relief': 136,
#  'forex': 136,
#  'highest': 136,
#  'b': 136,
#  'stood': 136,
#  'able': 136,
#  'cty': 136,
#  'pvs': 136,
#  'falling': 135,
#  'gas': 135,
#  'core': 135,
#  'today': 134,
#  'bring': 134,
#  'ensure': 134,
#  'tokyo': 134,
#  'immediately': 134,
#  'institutions': 134,
#  'act': 134,
#  'execution': 134,
#  'chile': 133,
#  'plus': 133,
#  'outside': 133,
#  'sharply': 133,
#  'speculation': 133,
#  'cusip': 133,
#  'hopes': 133,
#  'belgian': 133,
#  'additional': 133,
#  'qualify': 133,
#  'capacity': 132,
#  'ratings': 132,
#  'run': 132,
#  'finances': 132,
#  'household': 132,
#  'canadian': 132,
#  'beijing': 132,
#  'circulation': 131,
#  'times': 131,
#  'area': 131,
#  'life': 130,
#  'organisation': 130,
#  'agreements': 130,
#  'trust': 130,
#  'launched': 130,
#  'bids': 130,
#  'rule': 129,
#  'zealand': 129,
#  'executive': 129,
#  'buy': 129,
#  'limit': 129,
#  'pilots': 129,
#  'enough': 129,
#  'though': 128,
#  'dtp': 128,
#  'peace': 128,
#  'cooperation': 128,
#  'unit': 127,
#  'near': 127,
#  'finnish': 126,
#  'socialist': 126,
#  'targets': 126,
#  'stg': 125,
#  'hoped': 125,
#  'standard': 125,
#  'lost': 125,
#  'philippines': 125,
#  'problem': 125,
#  'francs': 125,
#  'gordon': 124,
#  'included': 124,
#  'corporation': 124,
#  'passed': 124,
#  'federation': 124,
#  'benefit': 123,
#  'nine': 123,
#  'stearns': 123,
#  'communist': 123,
#  'fuel': 122,
#  'mortgage': 122,
#  'whose': 122,
#  'probably': 122,
#  'elections': 122,
#  'forced': 122,
#  'refunding': 122,
#  'suggested': 122,
#  'release': 121,
#  'program': 121,
#  'accounts': 121,
#  'review': 121,
#  'steady': 120,
#  'create': 120,
#  'abroad': 120,
#  'assembly': 120,
#  'personal': 119,
#  'concerns': 119,
#  'falls': 119,
#  'approval': 119,
#  'media': 119,
#  'raising': 119,
#  'selling': 118,
#  'exchequer': 118,
#  'limited': 118,
#  'found': 118,
#  'try': 118,
#  'fixed': 118,
#  'sold': 118,
#  'airways': 117,
#  'paris': 117,
#  'civil': 117,
#  'joint': 117,
#  'reduction': 117,
#  'addition': 117,
#  'means': 117,
#  'believe': 117,
#  'signs': 117,
#  'human': 117,
#  'summer': 117,
#  'korean': 117,
#  'england': 116,
#  'proposals': 116,
#  'weekend': 116,
#  'weak': 116,
#  'millions': 116,
#  'changed': 116,
#  'improve': 115,
#  'begin': 115,
#  'accord': 115,
#  'estimate': 115,
#  'losses': 115,
#  'push': 115,
#  'philippine': 115,
#  ...}

# %%
def top1000nouns(freqdist,k=1000):
  return sorted(freqdist.items(),key=operator.itemgetter(1),reverse=True)[:k] #returns list of sorted frequency of top 1000 noun senses
topnouns = top1000nouns(sortednouns)
topnouns
# Out:
# [('said', 12706),
#  ('percent', 8142),
#  ('would', 4296),
#  ('million', 4046),
#  ('pct', 3989),
#  ('year', 3983),
#  ('bank', 3876),
#  ('may', 3728),
#  ('billion', 3393),
#  ('government', 3120),
#  ('trade', 2760),
#  ('tax', 2591),
#  ('economic', 2314),
#  ('last', 2235),
#  ('rate', 2164),
#  ('budget', 2156),
#  ('new', 2130),
#  ('june', 2122),
#  ('minister', 2045),
#  ('growth', 1995),
#  ('first', 1936),
#  ('april', 1920),
#  ('also', 1789),
#  ('price', 1765),
#  ('union', 1752),
#  ('central', 1739),
#  ('balance', 1678),
#  ('bonds', 1671),
#  ('state', 1667),
#  ('inflation', 1662),
#  ('finance', 1603),
#  ('total', 1592),
#  ('bln', 1550),
#  ('foreign', 1527),
#  ('march', 1496),
#  ('gdp', 1477),
#  ('prices', 1449),
#  ('expected', 1442),
#  ('wednesday', 1417),
#  ('index', 1410),
#  ('deficit', 1397),
#  ('tuesday', 1391),
#  ('could', 1378),
#  ('currency', 1357),
#  ('due', 1354),
#  ('economy', 1350),
#  ('thursday', 1346),
#  ('week', 1344),
#  ('july', 1344),
#  ('market', 1319),
#  ('rates', 1275),
#  ('change', 1271),
#  ('interest', 1263),
#  ('exports', 1234),
#  ('two', 1233),
#  ('european', 1212),
#  ('one', 1181),
#  ('officials', 1158),
#  ('monday', 1143),
#  ('monetary', 1142),
#  ('friday', 1136),
#  ('current', 1119),
#  ('years', 1091),
#  ('rise', 1082),
#  ('official', 1080),
#  ('month', 1079),
#  ('debt', 1065),
#  ('coupon', 1048),
#  ('delivery', 1029),
#  ('maturity', 1018),
#  ('call', 1018),
#  ('rose', 1001),
#  ('sales', 995),
#  ('time', 978),
#  ('series', 978),
#  ('strike', 976),
#  ('imports', 971),
#  ('capital', 968),
#  ('president', 967),
#  ('apr', 966),
#  ('analysts', 963),
#  ('investment', 959),
#  ('issue', 958),
#  ('domestic', 954),
#  ('next', 953),
#  ('public', 952),
#  ('unemployment', 947),
#  ('three', 931),
#  ('amount', 929),
#  ('japan', 910),
#  ('china', 887),
#  ('country', 868),
#  ('told', 855),
#  ('sale', 854),
#  ('consumer', 851),
#  ('period', 850),
#  ('cut', 848),
#  ('months', 848),
#  ('money', 847),
#  ('reserves', 845),
#  ('sector', 841),
#  ('eu', 836),
#  ('p', 834),
#  ('moody', 829),
#  ('quarter', 818),
#  ('workers', 817),
#  ('international', 816),
#  ('aaa', 812),
#  ('date', 812),
#  ('financial', 805),
#  ('end', 802),
#  ('national', 801),
#  ('germany', 797),
#  ('policy', 793),
#  ('inc', 787),
#  ('emu', 786),
#  ('business', 784),
#  ('economists', 781),
#  ('talks', 770),
#  ('german', 764),
#  ('yield', 763),
#  ('prime', 756),
#  ('data', 755),
#  ('figures', 753),
#  ('bond', 747),
#  ('countries', 746),
#  ('company', 745),
#  ('since', 743),
#  ('markets', 738),
#  ('meeting', 736),
#  ('general', 735),
#  ('spending', 735),
#  ('labour', 732),
#  ('house', 731),
#  ('states', 724),
#  ('south', 709),
#  ('treasury', 709),
#  ('mln', 703),
#  ('increase', 694),
#  ('forecast', 692),
#  ('plan', 686),
#  ('industry', 683),
#  ('exchange', 678),
#  ('plans', 678),
#  ('ministry', 677),
#  ('banks', 677),
#  ('world', 668),
#  ('bill', 660),
#  ('united', 655),
#  ('output', 649),
#  ('revenue', 645),
#  ('added', 636),
#  ('companies', 635),
#  ('oil', 634),
#  ('credit', 633),
#  ('france', 627),
#  ('gross', 626),
#  ('clinton', 624),
#  ('account', 620),
#  ('say', 620),
#  ('deal', 612),
#  ('feb', 611),
#  ('average', 608),
#  ('set', 605),
#  ('school', 602),
#  ('city', 600),
#  ('annual', 598),
#  ('private', 590),
#  ('services', 586),
#  ('mar', 583),
#  ('gold', 583),
#  ('net', 583),
#  ('cpi', 580),
#  ('pay', 578),
#  ('report', 576),
#  ('jobs', 575),
#  ('earlier', 574),
#  ('county', 574),
#  ('latest', 572),
#  ('agreement', 572),
#  ('still', 570),
#  ('note', 568),
#  ('fiscal', 565),
#  ('orders', 563),
#  ('says', 554),
#  ('key', 553),
#  ('five', 552),
#  ('statement', 551),
#  ('fund', 550),
#  ('surplus', 545),
#  ('jul', 541),
#  ('dollar', 537),
#  ('europe', 536),
#  ('goods', 535),
#  ('industrial', 534),
#  ('aid', 530),
#  ('italy', 530),
#  ('single', 529),
#  ('british', 523),
#  ('fell', 522),
#  ('previous', 522),
#  ('federal', 521),
#  ('group', 520),
#  ('made', 516),
#  ('ago', 514),
#  ('compared', 513),
#  ('high', 513),
#  ('recent', 512),
#  ('seen', 510),
#  ('product', 509),
#  ('work', 508),
#  ('statistics', 508),
#  ('indicators', 507),
#  ('monthly', 506),
#  ('higher', 505),
#  ('french', 504),
#  ('meet', 502),
#  ('issuer', 501),
#  ('retail', 496),
#  ('likely', 495),
#  ('system', 492),
#  ('jun', 491),
#  ('local', 490),
#  ('features', 488),
#  ('lower', 486),
#  ('people', 486),
#  ('fall', 483),
#  ('leaders', 481),
#  ('real', 479),
#  ('second', 479),
#  ('district', 476),
#  ('around', 476),
#  ('reform', 475),
#  ('news', 471),
#  ('help', 469),
#  ('following', 462),
#  ('demand', 462),
#  ('service', 462),
#  ('russia', 462),
#  ('final', 461),
#  ('brazil', 461),
#  ('february', 456),
#  ('imf', 454),
#  ('per', 451),
#  ('britain', 450),
#  ('cuts', 449),
#  ('north', 448),
#  ('firms', 445),
#  ('showed', 445),
#  ('level', 444),
#  ('back', 444),
#  ('take', 443),
#  ('food', 442),
#  ('planned', 442),
#  ('reuters', 437),
#  ('thailand', 434),
#  ('major', 433),
#  ('india', 433),
#  ('investors', 429),
#  ('four', 429),
#  ('make', 427),
#  ('committee', 425),
#  ('strong', 424),
#  ('reserve', 421),
#  ('members', 421),
#  ('production', 420),
#  ('parliament', 419),
#  ('six', 418),
#  ('none', 417),
#  ('development', 414),
#  ('saying', 412),
#  ('us', 411),
#  ('much', 407),
#  ('manufacturing', 406),
#  ('start', 404),
#  ('spokesman', 398),
#  ('including', 398),
#  ('aug', 397),
#  ('export', 396),
#  ('income', 395),
#  ('already', 393),
#  ('reforms', 393),
#  ('st', 392),
#  ('reported', 389),
#  ('board', 389),
#  ('canada', 387),
#  ('notes', 386),
#  ('cost', 386),
#  ('enhancements', 385),
#  ('funds', 385),
#  ('must', 384),
#  ('agreed', 383),
#  ('day', 383),
#  ('employment', 381),
#  ('part', 380),
#  ('despite', 379),
#  ('well', 376),
#  ('measures', 376),
#  ('number', 375),
#  ('firm', 373),
#  ('half', 371),
#  ('january', 369),
#  ('many', 369),
#  ('party', 368),
#  ('housing', 367),
#  ('kohl', 366),
#  ('department', 363),
#  ('taxes', 363),
#  ('office', 360),
#  ('securities', 357),
#  ('social', 356),
#  ('authority', 356),
#  ('even', 354),
#  ('supply', 353),
#  ('go', 353),
#  ('australia', 351),
#  ('move', 350),
#  ('survey', 349),
#  ('wage', 349),
#  ('see', 348),
#  ('basis', 348),
#  ('uk', 347),
#  ('points', 347),
#  ('called', 347),
#  ('obligation', 346),
#  ('decision', 345),
#  ('stat', 345),
#  ('na', 345),
#  ('korea', 345),
#  ('low', 344),
#  ('unions', 344),
#  ('changes', 344),
#  ('bundesbank', 343),
#  ('target', 342),
#  ('support', 342),
#  ('conference', 341),
#  ('mexico', 340),
#  ('august', 339),
#  ('political', 339),
#  ('congress', 339),
#  ('fed', 338),
#  ('list', 336),
#  ('japanese', 335),
#  ('announced', 334),
#  ('payments', 334),
#  ('past', 334),
#  ('agency', 334),
#  ('co', 333),
#  ('forecasts', 333),
#  ('days', 332),
#  ('brown', 331),
#  ('loans', 331),
#  ('senior', 331),
#  ('summit', 330),
#  ('nations', 327),
#  ('australian', 323),
#  ('economist', 322),
#  ('deposits', 322),
#  ('marks', 322),
#  ('sr', 322),
#  ('chief', 322),
#  ('governor', 321),
#  ('czech', 321),
#  ('qual', 319),
#  ('revenues', 319),
#  ('senate', 318),
#  ('early', 318),
#  ('ahead', 317),
#  ('taiwan', 316),
#  ('former', 315),
#  ('jan', 315),
#  ('indicator', 314),
#  ('euro', 314),
#  ('way', 314),
#  ('conc', 314),
#  ('mgr', 313),
#  ('whether', 312),
#  ('commission', 312),
#  ('far', 312),
#  ('according', 311),
#  ('continue', 310),
#  ('wages', 307),
#  ('free', 306),
#  ('secretary', 305),
#  ('improvement', 305),
#  ('issues', 305),
#  ('percentage', 305),
#  ('gmt', 304),
#  ('health', 304),
#  ('opposition', 304),
#  ('privatisation', 303),
#  ('raise', 302),
#  ('ministers', 302),
#  ('washington', 301),
#  ('increased', 301),
#  ('put', 296),
#  ('pricing', 295),
#  ('released', 294),
#  ('costs', 294),
#  ('russian', 293),
#  ('construction', 293),
#  ('another', 292),
#  ('conditions', 291),
#  ('issued', 291),
#  ('future', 291),
#  ('seven', 291),
#  ('morgan', 291),
#  ('stock', 291),
#  ('later', 290),
#  ('building', 289),
#  ('kong', 288),
#  ('power', 288),
#  ('rating', 288),
#  ('hong', 287),
#  ('law', 287),
#  ('smith', 287),
#  ('base', 285),
#  ('need', 283),
#  ('spain', 283),
#  ('approved', 283),
#  ('yen', 282),
#  ('bonn', 282),
#  ('election', 281),
#  ('less', 281),
#  ('programme', 281),
#  ('thai', 280),
#  ('labor', 278),
#  ('chancellor', 278),
#  ('terms', 277),
#  ('trillion', 276),
#  ('commercial', 275),
#  ('sunday', 273),
#  ('stability', 273),
#  ('boost', 273),
#  ('criteria', 273),
#  ('approx', 272),
#  ('sources', 272),
#  ('use', 271),
#  ('value', 270),
#  ('proposed', 268),
#  ('import', 268),
#  ('late', 268),
#  ('possible', 266),
#  ('region', 265),
#  ('loan', 264),
#  ('given', 264),
#  ('good', 264),
#  ('preliminary', 264),
#  ('give', 263),
#  ('africa', 263),
#  ('white', 260),
#  ('get', 260),
#  ('deputy', 259),
#  ('overall', 259),
#  ('levels', 259),
#  ('leader', 259),
#  ('council', 258),
#  ('without', 258),
#  ('avg', 257),
#  ('based', 257),
#  ('problems', 257),
#  ('pact', 257),
#  ('action', 256),
#  ('long', 256),
#  ('notice', 255),
#  ('coalition', 254),
#  ('hit', 253),
#  ('details', 252),
#  ('cash', 252),
#  ('saturday', 252),
#  ('chairman', 251),
#  ('tonnes', 251),
#  ('needed', 250),
#  ('full', 249),
#  ('security', 249),
#  ('main', 249),
#  ('waigel', 249),
#  ('job', 249),
#  ('within', 249),
#  ('products', 249),
#  ('come', 248),
#  ('mark', 247),
#  ('tic', 246),
#  ('barney', 246),
#  ('poland', 244),
#  ('grew', 244),
#  ('vote', 244),
#  ('adjusted', 244),
#  ('pressure', 243),
#  ('used', 243),
#  ('leading', 243),
#  ('producer', 242),
#  ('baht', 242),
#  ('join', 242),
#  ('education', 241),
#  ('top', 241),
#  ('iraq', 241),
#  ('trading', 239),
#  ('negotiations', 239),
#  ('banking', 239),
#  ('rising', 239),
#  ('member', 239),
#  ('savings', 239),
#  ('source', 238),
#  ('confidence', 238),
#  ('might', 238),
#  ('american', 238),
#  ('among', 238),
#  ('subject', 237),
#  ('sees', 237),
#  ('east', 235),
#  ('held', 235),
#  ('treaty', 235),
#  ('hungary', 235),
#  ('little', 234),
#  ('reached', 234),
#  ('september', 233),
#  ('israel', 232),
#  ('energy', 232),
#  ('point', 232),
#  ('employees', 231),
#  ('available', 230),
#  ('minimum', 229),
#  ('close', 229),
#  ('poll', 228),
#  ('association', 228),
#  ('nic', 227),
#  ('show', 227),
#  ('dollars', 227),
#  ('term', 227),
#  ('largest', 226),
#  ('ba', 225),
#  ('institute', 225),
#  ('legislation', 225),
#  ('special', 224),
#  ('keep', 224),
#  ('result', 224),
#  ('par', 224),
#  ('revised', 224),
#  ('staff', 223),
#  ('weeks', 223),
#  ('reduce', 223),
#  ('open', 223),
#  ('newspaper', 222),
#  ('like', 222),
#  ('working', 222),
#  ('comment', 222),
#  ('administration', 222),
#  ('poor', 222),
#  ('proposal', 221),
#  ('worth', 221),
#  ('sell', 221),
#  ('allow', 220),
#  ('projects', 220),
#  ('transport', 219),
#  ('maastricht', 219),
#  ('york', 219),
#  ('shares', 218),
#  ('large', 218),
#  ('rises', 218),
#  ('c', 218),
#  ('several', 217),
#  ('management', 217),
#  ('force', 217),
#  ('daily', 217),
#  ('range', 216),
#  ('least', 216),
#  ('raised', 216),
#  ('reporters', 215),
#  ('order', 215),
#  ('london', 214),
#  ('water', 213),
#  ('figure', 213),
#  ('clear', 212),
#  ('bulgaria', 212),
#  ('package', 211),
#  ('yr', 211),
#  ('de', 211),
#  ('declined', 211),
#  ('estimated', 211),
#  ('small', 211),
#  ('indonesia', 211),
#  ('big', 210),
#  ('air', 210),
#  ('paper', 209),
#  ('african', 209),
#  ('policies', 209),
#  ('expect', 208),
#  ('sep', 207),
#  ('initial', 205),
#  ('bid', 205),
#  ('property', 205),
#  ('impact', 205),
#  ('trend', 205),
#  ('project', 205),
#  ('delay', 204),
#  ('operations', 203),
#  ('plant', 203),
#  ('yet', 203),
#  ('pounds', 202),
#  ('expectations', 201),
#  ('port', 201),
#  ('share', 201),
#  ('dealers', 201),
#  ('democrats', 200),
#  ('eight', 200),
#  ('cabinet', 199),
#  ('singapore', 199),
#  ('unchanged', 198),
#  ('court', 198),
#  ('gm', 198),
#  ('external', 198),
#  ('record', 197),
#  ('dispute', 197),
#  ('met', 197),
#  ('reach', 196),
#  ('launch', 196),
#  ('rules', 195),
#  ('remain', 195),
#  ('italian', 195),
#  ('control', 195),
#  ('wholesale', 195),
#  ('crisis', 194),
#  ('hold', 194),
#  ('decline', 193),
#  ('offer', 192),
#  ('line', 192),
#  ('efforts', 191),
#  ('nearly', 191),
#  ('third', 189),
#  ('ended', 188),
#  ('nation', 187),
#  ('december', 187),
#  ('romania', 187),
#  ('although', 186),
#  ('corporate', 186),
#  ('jobless', 186),
#  ('urged', 186),
#  ('wants', 186),
#  ('currently', 186),
#  ('gave', 185),
#  ('earnings', 185),
#  ('vs', 185),
#  ('polish', 185),
#  ('contract', 184),
#  ('director', 184),
#  ('consumption', 183),
#  ('majority', 183),
#  ('investments', 183),
#  ('population', 182),
#  ('taken', 182),
#  ('head', 182),
#  ('ups', 182),
#  ('republican', 181),
#  ('west', 181),
#  ('ruling', 181),
#  ('think', 180),
#  ('discuss', 180),
#  ('drop', 180),
#  ('growing', 180),
#  ('recovery', 180),
#  ('assets', 179),
#  ('want', 179),
#  ('bankers', 179),
#  ('wheat', 179),
#  ('malaysia', 178),
#  ('seasonally', 178),
#  ('asian', 177),
#  ('argentina', 177),
#  ('california', 177),
#  ('war', 177),
#  ('warned', 177),
#  ('global', 177),
#  ('goldman', 176),
#  ('jospin', 176),
#  ('rand', 176),
#  ('authorities', 176),
#  ('portugal', 176),
#  ('continued', 176),
#  ('noted', 175),
#  ('western', 175),
#  ('however', 175),
#  ('progress', 175),
#  ('soon', 174),
#  ('indian', 174),
#  ('america', 174),
#  ('effect', 173),
#  ('john', 173),
#  ('lead', 173),
#  ('saw', 173),
#  ('october', 173),
#  ('remained', 173),
#  ('auction', 172),
#  ('stocks', 172),
#  ('commerce', 172),
#  ('fitch', 171),
#  ('view', 171),
#  ('provide', 171),
#  ('making', 171),
#  ('consensus', 171),
#  ('sachs', 170),
#  ('research', 170),
#  ('pension', 170),
#  ('case', 170),
#  ('quoted', 170),
#  ('hours', 170),
#  ('regional', 169),
#  ('pakistan', 169),
#  ('weekly', 169),
#  ('membership', 169),
#  ('led', 169),
#  ('police', 168),
#  ('place', 168),
#  ('george', 168),
#  ('received', 168),
#  ('lending', 168),
#  ('scheduled', 167),
#  ('left', 167),
#  ('visit', 167),
#  ('rights', 166),
#  ('gap', 166),
#  ('yields', 166),
#  ('areas', 165),
#  ('failed', 165),
#  ('home', 164),
#  ('unlikely', 164),
#  ('asia', 163),
#  ('liquidity', 163),
#  ('stable', 163),
#  ('focus', 162),
#  ('sanctions', 162),
#  ('paid', 162),
#  ('profits', 161),
#  ('groups', 161),
#  ('entry', 161),
#  ('eastern', 161),
#  ('began', 161),
#  ('gains', 160),
#  ('republic', 160),
#  ('outlook', 160),
#  ('signed', 160),
#  ('funding', 160),
#  ('quarterly', 159),
#  ('traders', 159),
#  ('award', 159),
#  ('chinese', 159),
#  ('increases', 159),
#  ('bear', 159),
#  ('slovak', 159),
#  ('wanted', 158),
#  ('n', 158),
#  ('benefits', 158),
#  ('position', 158),
#  ('include', 158),
#  ('flights', 157),
#  ('aimed', 157),
#  ('present', 157),
#  ('bills', 157),
#  ('slow', 156),
#  ('hard', 156),
#  ('corp', 156),
#  ('theo', 156),
#  ('seek', 156),
#  ('return', 156),
#  ('independent', 155),
#  ('street', 155),
#  ('debate', 155),
#  ('speaking', 155),
#  ('table', 155),
#  ('reports', 154),
#  ('dutch', 154),
#  ('partners', 154),
#  ('finland', 154),
#  ('needs', 154),
#  ('lawmakers', 154),
#  ('sweden', 154),
#  ('wto', 154),
#  ('taking', 153),
#  ('sign', 153),
#  ('protest', 153),
#  ('eurobond', 153),
#  ('coming', 153),
#  ('measure', 153),
#  ('updated', 153),
#  ('interview', 152),
#  ('businesses', 152),
#  ('texas', 152),
#  ('industries', 152),
#  ('republicans', 152),
#  ('process', 151),
#  ('crowns', 151),
#  ('expansion', 151),
#  ('important', 151),
#  ('panel', 150),
#  ('concern', 150),
#  ('borrowing', 150),
#  ('dean', 150),
#  ('deficits', 150),
#  ('planning', 149),
#  ('facilities', 149),
#  ('asked', 149),
#  ('community', 149),
#  ('recently', 149),
#  ('positive', 149),
#  ('expenditure', 149),
#  ('grow', 149),
#  ('billions', 148),
#  ('iran', 148),
#  ('volume', 148),
#  ('direct', 148),
#  ('sectors', 148),
#  ('activity', 147),
#  ('dec', 147),
#  ('conservative', 147),
#  ('sterling', 147),
#  ('currencies', 146),
#  ('ratio', 146),
#  ('witter', 146),
#  ('plc', 145),
#  ('risk', 145),
#  ('agriculture', 145),
#  ('military', 145),
#  ('short', 145),
#  ('financing', 145),
#  ('allowed', 144),
#  ('dropped', 144),
#  ('right', 144),
#  ('democratic', 144),
#  ('press', 144),
#  ('parliamentary', 143),
#  ('slightly', 143),
#  ('offered', 142),
#  ('prev', 142),
#  ('took', 142),
#  ('stanley', 142),
#  ('become', 142),
#  ('employers', 142),
#  ('rather', 142),
#  ('ltd', 141),
#  ('better', 141),
#  ('vietnam', 141),
#  ('welfare', 141),
#  ('insurance', 140),
#  ('pace', 140),
#  ('mainly', 140),
#  ('ukraine', 140),
#  ('swiss', 140),
#  ('lowest', 139),
#  ('published', 139),
#  ('towards', 139),
#  ('speech', 139),
#  ('face', 139),
#  ('looking', 139),
#  ('alternative', 139),
#  ('fbs', 139),
#  ('almost', 139),
#  ('seeking', 139),
#  ('november', 139),
#  ('results', 138),
#  ('going', 138),
#  ('tourism', 138),
#  ('came', 138),
#  ('car', 138),
#  ('municipal', 138),
#  ('site', 138),
#  ('spread', 137),
#  ('biggest', 137),
#  ('helmut', 137),
#  ('spokeswoman', 137),
#  ('relief', 136),
#  ('forex', 136),
#  ('highest', 136),
#  ('b', 136),
#  ('stood', 136),
#  ('able', 136),
#  ('cty', 136),
#  ('pvs', 136),
#  ('falling', 135),
#  ('gas', 135),
#  ('core', 135),
#  ('today', 134),
#  ('bring', 134),
#  ('ensure', 134),
#  ('tokyo', 134),
#  ('immediately', 134),
#  ('institutions', 134),
#  ('act', 134),
#  ('execution', 134),
#  ('chile', 133),
#  ('plus', 133),
#  ('outside', 133),
#  ('sharply', 133),
#  ('speculation', 133),
#  ('cusip', 133),
#  ('hopes', 133),
#  ('belgian', 133),
#  ('additional', 133),
#  ('qualify', 133),
#  ('capacity', 132),
#  ('ratings', 132),
#  ('run', 132),
#  ('finances', 132),
#  ('household', 132),
#  ('canadian', 132),
#  ('beijing', 132),
#  ('circulation', 131),
#  ('times', 131),
#  ('area', 131),
#  ('life', 130),
#  ('organisation', 130),
#  ('agreements', 130),
#  ('trust', 130),
#  ('launched', 130),
#  ('bids', 130),
#  ('rule', 129),
#  ('zealand', 129),
#  ('executive', 129),
#  ('buy', 129),
#  ('limit', 129),
#  ('pilots', 129),
#  ('enough', 129),
#  ('though', 128),
#  ('dtp', 128),
#  ('peace', 128),
#  ('cooperation', 128),
#  ('unit', 127),
#  ('near', 127),
#  ('finnish', 126),
#  ('socialist', 126),
#  ('targets', 126),
#  ('stg', 125),
#  ('hoped', 125),
#  ('standard', 125),
#  ('lost', 125),
#  ('philippines', 125),
#  ('problem', 125),
#  ('francs', 125),
#  ('gordon', 124),
#  ('included', 124),
#  ('corporation', 124),
#  ('passed', 124),
#  ('federation', 124),
#  ('benefit', 123),
#  ('nine', 123),
#  ('stearns', 123),
#  ('communist', 123),
#  ('fuel', 122),
#  ('mortgage', 122),
#  ('whose', 122),
#  ('probably', 122),
#  ('elections', 122),
#  ('forced', 122),
#  ('refunding', 122),
#  ('suggested', 122),
#  ('release', 121),
#  ('program', 121),
#  ('accounts', 121),
#  ('review', 121),
#  ('steady', 120),
#  ('create', 120),
#  ('abroad', 120),
#  ('assembly', 120),
#  ('personal', 119),
#  ('concerns', 119),
#  ('falls', 119),
#  ('approval', 119),
#  ('media', 119),
#  ('raising', 119),
#  ('selling', 118),
#  ('exchequer', 118),
#  ('limited', 118),
#  ('found', 118),
#  ('try', 118),
#  ('fixed', 118),
#  ('sold', 118),
#  ('airways', 117),
#  ('paris', 117),
#  ('civil', 117),
#  ('joint', 117),
#  ('reduction', 117),
#  ('addition', 117),
#  ('means', 117),
#  ('believe', 117),
#  ('signs', 117),
#  ('human', 117),
#  ('summer', 117),
#  ('korean', 117),
#  ('england', 116),
#  ('proposals', 116),
#  ('weekend', 116),
#  ('weak', 116),
#  ('millions', 116),
#  ('changed', 116),
#  ('improve', 115),
#  ('begin', 115),
#  ('accord', 115),
#  ('estimate', 115),
#  ('losses', 115),
#  ('push', 115),
#  ('philippine', 115)]

# %%
#do not change the code in this cell.  It relates to Q3
wordpair=("house","garden")
concept_1=wn.synsets(wordpair[0])[0]
concept_2=wn.synsets(wordpair[1])[0]
print("Path similarity between 1st sense of {} and 1st sense of {} is {}".format(wordpair[0],wordpair[1],wn.path_similarity(concept_1,concept_2)))
print("Resnik similarity between 1st sense of {} and 1st sense of {} is {}".format(wordpair[0],wordpair[1],wn.res_similarity(concept_1,concept_2, brown_ic)))
print("Lin similarity between 1st sense of {} and 1st sense of {} is {}".format(wordpair[0],wordpair[1],wn.lin_similarity(concept_1,concept_2, brown_ic)))
# Out:
# Path similarity between 1st sense of house and 1st sense of garden is 0.08333333333333333
# Resnik similarity between 1st sense of house and 1st sense of garden is 1.2900256809649917
# Lin similarity between 1st sense of house and 1st sense of garden is 0.15380807721262396

# %% [markdown]
# 3) Consider the code above which outputs the path similarity score, the Resnik similarity score and the Lin similarity score for a pair of concepts in WordNet.  Answer the following questions.
#
# a) Explain what each of the numbers in the output means.
#
# b) Write code to find the semantic similarity of a pair of words according to WordNet with a parameter to specify the measure of semantic similarity between concepts.  Explain and justify the strategy used for words which have multiple senses.
#
# c) Choose one of the measures of semantic similarity and then for every possible pair of words identified in Q2, determine the semantic similarity of the pair according to WordNet.  Justify your choice of semantic similarity measure.
#
# d) Identify the 10 most similar words (according to WordNet) to the most frequent word in the corpus [20 marks]

# %% [markdown]
# 3. A  Explain what each of the numbers in the output means.
#
# >The path similarity returns a score in a range of 0 to 1 which determines how similar two word senses are, based on the shortest path that connects the senses through taxonomy.
#
# >The Resnik similarity returns a score to determine how similar two word senses are based on the information content of the least common subsumer.
#
# >The Lin similarity returns a score to determine how similar two word senses are based on the information conent of the least common subsumer and of the two input synsets.
#
# 3. B Write code to find the semantic similarity of a pair of words according to WordNet with a parameter to specify the measure of semantic similarity between concepts. Explain and justify the strategy used for words which have multiple senses.
#
# > When coming across multiple senses a strategy to use could be supervised methods, by using human judgement and associating the answer with it. Because a human can understand the grammar, structure and choice of a chosen word so the machine can learn and adapt to that choice.

# %%
def word_similarity(wordA,wordB,pos=wn.NOUN,measure="path"): #method taking in parameters for word1 word2 and the type of measure
    synsetsA=wn.synsets(wordA,pos) #creates synset for chosen word
    synsetsB=wn.synsets(wordB,pos) #creates synset for chosen word
    maxsofar=0
    path = "similarity title" #sets default type of measure
    brown_ic=wn_ic.ic("ic-brown.dat")
    for synsetA in synsetsA:
        for synsetB in synsetsB:
            if measure=="path": #checks type of measure
                sim=wn.path_similarity(synsetA,synsetB)
                path = "Path similarity " #changes type of measure accordingly
            elif measure=="resnik": #checks type of measure
                sim=wn.res_similarity(synsetA,synsetB,brown_ic)
                path = "Resnik similarity" #changes type of measure accordingly
            elif measure=="lin": #checks type of measure
                sim=wn.lin_similarity(synsetA,synsetB,brown_ic)
                path = "Lin similarity " #changes type of measure accordingly
            
            if sim>maxsofar: #checks if similarity is at its highest point
                maxsofar=sim
    print("{} between {} and {} is {}".format(path,wordA,wordB,maxsofar)) #prints in a set format 

word_similarity("cat","dog",measure="path")
word_similarity("cat","dog",measure="resnik")
word_similarity("cat","dog",measure="lin")
# Out:
# Path similarity  between cat and dog is 0.2
# Resnik similarity between cat and dog is 7.911666509036577
# Lin similarity  between cat and dog is 0.8768009843733973

# %% [markdown]
# 3. C  Choose one of the measures of semantic similarity and then for every possible pair of words identified in Q2, determine the semantic similarity of the pair according to WordNet. Justify your choice of semantic similarity measure.

# %% [markdown]
# Lin similarity returns a score to determine how similar two word senses are based on the information conent of the least common subsumer and of the two input synsets. I chose lin similarity because it takes the information content of compared concepts into consideration. With path similarity two pairs with equal lengths of the shortest path will have the same similarity which isn't helpful and with resnik similarity two pairs with the same lowest common subsumer will have the same similarity which also doesnt help. Therefore making lin similarity a more accurate approach.

# %%
def lin_similarity(wordA,wordB,pos=wn.NOUN):
    synsetsA=wn.synsets(wordA,pos) #puts words into synsets
    synsetsB=wn.synsets(wordB,pos) #puts words into synsets
    maxsofar=0
    for synsetA in synsetsA:
        for synsetB in synsetsB:
            sim=wn.lin_similarity(synsetA,synsetB,brown_ic) #uses lin on word synsets
            if sim>maxsofar:
                maxsofar=sim
    print("Lin similarity between {} and {} is {}".format(wordA,wordB,maxsofar))
lin_similarity("chicken","car")
# Out:
# Lin similarity between chicken and car is 0.17900106582025765

# %%
wordstopair = top1000nouns(sortednouns)
wordstopair
for i in range(0,len(wordstopair)): #loops through eveyr word
  for j in range(i + 1, len(wordstopair)): # nested loop to then cover every word ahead of the previous loop of words, thus covering every word with every word
    lin_similarity(wordstopair[i][0],wordstopair[j][0]) #conducts lin similarity check with each given pair of words
# Out:
# Streaming output truncated to the last 5000 lines.
# Lin similarity between ratings and elections is 0.49617138095124536
# Lin similarity between ratings and forced is 0
# Lin similarity between ratings and refunding is 0
# Lin similarity between ratings and suggested is 0
# Lin similarity between ratings and release is 0.24192091816462227
# Lin similarity between ratings and program is 0.35674075471326744
# Lin similarity between ratings and accounts is 0.2955897861702772
# Lin similarity between ratings and review is 0.8505368311357361
# Lin similarity between ratings and steady is 0
# Lin similarity between ratings and create is 0
# Lin similarity between ratings and abroad is 0
# Lin similarity between ratings and assembly is 0.2684889690283737
# Lin similarity between ratings and personal is 0.0663488187969821
# Lin similarity between ratings and concerns is 0.3467270079752856
# Lin similarity between ratings and falls is 0.3163025522754525
# Lin similarity between ratings and approval is 0.29763310319031716
# Lin similarity between ratings and media is 0.28718967830251657
# Lin similarity between ratings and raising is 0.22713458939046188
# Lin similarity between ratings and selling is 0.2534888722066921
# Lin similarity between ratings and exchequer is 0.060369195722374716
# Lin similarity between ratings and limited is 0
# Lin similarity between ratings and found is 0.07085169905422968
# Lin similarity between ratings and try is 0.28838488112775407
# Lin similarity between ratings and fixed is 0
# Lin similarity between ratings and sold is 0
# Lin similarity between ratings and airways is 0.05822266140597935
# Lin similarity between ratings and paris is 0.2796161411385405
# Lin similarity between ratings and civil is 0
# Lin similarity between ratings and joint is 0.21646252304820376
# Lin similarity between ratings and reduction is 0.26494863903389326
# Lin similarity between ratings and addition is 0.2382659705785473
# Lin similarity between ratings and means is 0.3134801272046409
# Lin similarity between ratings and believe is 0
# Lin similarity between ratings and signs is 0.2933066800790203
# Lin similarity between ratings and human is 0
# Lin similarity between ratings and summer is 0.06610572966515395
# Lin similarity between ratings and korean is 0.05667411745942812
# Lin similarity between ratings and england is 0
# Lin similarity between ratings and proposals is 0.23584841690798214
# Lin similarity between ratings and weekend is 0.06085928225588219
# Lin similarity between ratings and weak is 0
# Lin similarity between ratings and millions is 0.06884479788793749
# Lin similarity between ratings and changed is 0
# Lin similarity between ratings and improve is 0
# Lin similarity between ratings and begin is 0
# Lin similarity between ratings and accord is 0.31356572093190815
# Lin similarity between ratings and estimate is 0.8047083709078391
# Lin similarity between ratings and losses is 0.2464048070905655
# Lin similarity between ratings and push is 0.2590941204640918
# Lin similarity between ratings and philippine is 0.05667411745942812
# Lin similarity between run and finances is 0.34776324847529516
# Lin similarity between run and household is 0.35183547994454767
# Lin similarity between run and canadian is 0.6387384986984829
# Lin similarity between run and beijing is 0.07009376311474735
# Lin similarity between run and circulation is 0.6262170330423623
# Lin similarity between run and times is 0.5141821214443407
# Lin similarity between run and area is 0.4846226382149465
# Lin similarity between run and life is 0.4777398738005813
# Lin similarity between run and organisation is 0.4881766802472034
# Lin similarity between run and agreements is 0.3576022112932261
# Lin similarity between run and trust is 0.3827587960193539
# Lin similarity between run and launched is 0
# Lin similarity between run and bids is 0.7136874678615104
# Lin similarity between run and rule is 0.48189418466783207
# Lin similarity between run and zealand is 1.6035182299077988e-300
# Lin similarity between run and executive is 0.29090154658213246
# Lin similarity between run and buy is 0.06981401062800213
# Lin similarity between run and limit is 0.5818317583168691
# Lin similarity between run and pilots is 0.5623847282691681
# Lin similarity between run and enough is 0.27480381007788574
# Lin similarity between run and though is 0
# Lin similarity between run and dtp is 0
# Lin similarity between run and peace is 0.3372838557748143
# Lin similarity between run and cooperation is 0.3302299957786077
# Lin similarity between run and unit is 0.5611232767661095
# Lin similarity between run and near is 0
# Lin similarity between run and finnish is 0.05309159225489688
# Lin similarity between run and socialist is 0.09149941027997152
# Lin similarity between run and targets is 0.4416594632313851
# Lin similarity between run and stg is 0
# Lin similarity between run and hoped is 0
# Lin similarity between run and standard is 0.4880888257573696
# Lin similarity between run and lost is 0.31227718279462024
# Lin similarity between run and philippines is 0.07228390651574898
# Lin similarity between run and problem is 0.37319819414949795
# Lin similarity between run and francs is 0.24256932508263895
# Lin similarity between run and gordon is 0
# Lin similarity between run and included is 0
# Lin similarity between run and corporation is 0.42740564833929123
# Lin similarity between run and passed is 0
# Lin similarity between run and federation is 0.3999480795073578
# Lin similarity between run and benefit is 0.5796898958673377
# Lin similarity between run and nine is 0.3176008045871265
# Lin similarity between run and stearns is 0
# Lin similarity between run and communist is 0.08808636843643437
# Lin similarity between run and fuel is 0.09472903422559388
# Lin similarity between run and mortgage is 0.06156416871748898
# Lin similarity between run and whose is 0
# Lin similarity between run and probably is 0
# Lin similarity between run and elections is 0.4123760170860849
# Lin similarity between run and forced is 0
# Lin similarity between run and refunding is 0
# Lin similarity between run and suggested is 0
# Lin similarity between run and release is 0.6916262095773946
# Lin similarity between run and program is 0.8712971196876291
# Lin similarity between run and accounts is 0.3344094620060033
# Lin similarity between run and review is 0.5680723558509031
# Lin similarity between run and steady is 0.08189185870545496
# Lin similarity between run and create is 0
# Lin similarity between run and abroad is 0
# Lin similarity between run and assembly is 0.358908090510454
# Lin similarity between run and personal is 0.08704170370769436
# Lin similarity between run and concerns is 0.4013819494878771
# Lin similarity between run and falls is 0.7180055123534903
# Lin similarity between run and approval is 0.36845026456636804
# Lin similarity between run and media is 0.3421504723453726
# Lin similarity between run and raising is 0.6778370989308652
# Lin similarity between run and selling is 0.2852519779568736
# Lin similarity between run and exchequer is 0.0624549253513471
# Lin similarity between run and limited is 0.08661269944654026
# Lin similarity between run and found is 0.07374198644802965
# Lin similarity between run and try is 0.8532610147930694
# Lin similarity between run and fixed is 0
# Lin similarity between run and sold is 0
# Lin similarity between run and airways is 0.3692426542033669
# Lin similarity between run and paris is 0.2959288778965781
# Lin similarity between run and civil is 0
# Lin similarity between run and joint is 0.4517990221957542
# Lin similarity between run and reduction is 0.5116236391666514
# Lin similarity between run and addition is 0.5978631093678025
# Lin similarity between run and means is 0.3262352021247716
# Lin similarity between run and believe is 0
# Lin similarity between run and signs is 0.4518665879855066
# Lin similarity between run and human is 0.10657483001881755
# Lin similarity between run and summer is 0.4110019359194272
# Lin similarity between run and korean is 0.0753982183147104
# Lin similarity between run and england is 0.08455261941115931
# Lin similarity between run and proposals is 0.2631068240849666
# Lin similarity between run and weekend is 0.3791225483251356
# Lin similarity between run and weak is 0
# Lin similarity between run and millions is 0.5840900462152211
# Lin similarity between run and changed is 0
# Lin similarity between run and improve is 0
# Lin similarity between run and begin is 0.08587791357073152
# Lin similarity between run and accord is 0.3576022112932261
# Lin similarity between run and estimate is 0.3324492632705611
# Lin similarity between run and losses is 0.6916262095773946
# Lin similarity between run and push is 0.5307291992243974
# Lin similarity between run and philippine is 0.05850845530029538
# Lin similarity between finances and household is 0.07535101048402165
# Lin similarity between finances and canadian is 0
# Lin similarity between finances and beijing is 0
# Lin similarity between finances and circulation is 0.21834548941892984
# Lin similarity between finances and times is 0.3027815128652645
# Lin similarity between finances and area is 0.34582629021783473
# Lin similarity between finances and life is 0.3537711215707247
# Lin similarity between finances and organisation is 0.6873492055611962
# Lin similarity between finances and agreements is 0.33185558659218084
# Lin similarity between finances and trust is 0.478940823522808
# Lin similarity between finances and launched is 0
# Lin similarity between finances and bids is 0.27512833350437654
# Lin similarity between finances and rule is 0.33661182583791316
# Lin similarity between finances and zealand is 0
# Lin similarity between finances and executive is 0.062025838756321144
# Lin similarity between finances and buy is 0.5045979022064364
# Lin similarity between finances and limit is 0.06866512441304723
# Lin similarity between finances and pilots is 0.323384374342784
# Lin similarity between finances and enough is 0.06240818222795449
# Lin similarity between finances and though is 0
# Lin similarity between finances and dtp is 0
# Lin similarity between finances and peace is 0.06573436995653618
# Lin similarity between finances and cooperation is 0.521824993413279
# Lin similarity between finances and unit is 0.38248899265704467
# Lin similarity between finances and near is 0
# Lin similarity between finances and finnish is 0.05162964700660769
# Lin similarity between finances and socialist is 0
# Lin similarity between finances and targets is 0.36881847953253866
# Lin similarity between finances and stg is 0
# Lin similarity between finances and hoped is 0
# Lin similarity between finances and standard is 0.3402804697602598
# Lin similarity between finances and lost is 0.0666868846559597
# Lin similarity between finances and philippines is 0.056737945084897254
# Lin similarity between finances and problem is 0.28575271267835317
# Lin similarity between finances and francs is 0.05492644922736219
# Lin similarity between finances and gordon is 0
# Lin similarity between finances and included is 0
# Lin similarity between finances and corporation is 0.06694245816649626
# Lin similarity between finances and passed is 0
# Lin similarity between finances and federation is 0.21624367430294059
# Lin similarity between finances and benefit is 0.4910296024522872
# Lin similarity between finances and nine is 0.3287866925826167
# Lin similarity between finances and stearns is 0
# Lin similarity between finances and communist is 0
# Lin similarity between finances and fuel is 0
# Lin similarity between finances and mortgage is 0.5174233676308316
# Lin similarity between finances and whose is 0
# Lin similarity between finances and probably is 0
# Lin similarity between finances and elections is 0.48367777771659765
# Lin similarity between finances and forced is 0
# Lin similarity between finances and refunding is 0
# Lin similarity between finances and suggested is 0
# Lin similarity between finances and release is 0.24807489722431145
# Lin similarity between finances and program is 0.38481936351945306
# Lin similarity between finances and accounts is 0.26951852533556714
# Lin similarity between finances and review is 0.4525601762980153
# Lin similarity between finances and steady is 0
# Lin similarity between finances and create is 0
# Lin similarity between finances and abroad is 0
# Lin similarity between finances and assembly is 0.5355333558087348
# Lin similarity between finances and personal is 0.06643631496848755
# Lin similarity between finances and concerns is 0.28088731544043327
# Lin similarity between finances and falls is 0.27827915956419574
# Lin similarity between finances and approval is 0.2503186484133405
# Lin similarity between finances and media is 0.3277111192549814
# Lin similarity between finances and raising is 0.5550235554055419
# Lin similarity between finances and selling is 0.6823635353799387
# Lin similarity between finances and exchequer is 0.8749301412551723
# Lin similarity between finances and limited is 0
# Lin similarity between finances and found is 0.5319139777747213
# Lin similarity between finances and try is 0.2971727015295899
# Lin similarity between finances and fixed is 0
# Lin similarity between finances and sold is 0
# Lin similarity between finances and airways is 0.05829002676484847
# Lin similarity between finances and paris is 0.24948137332344036
# Lin similarity between finances and civil is 0
# Lin similarity between finances and joint is 0.32617964518634085
# Lin similarity between finances and reduction is 0.2723478501051173
# Lin similarity between finances and addition is 0.49465764702550347
# Lin similarity between finances and means is 0.5996690230629425
# Lin similarity between finances and believe is 0
# Lin similarity between finances and signs is 0.33640768762409673
# Lin similarity between finances and human is 0
# Lin similarity between finances and summer is 0.06619258545369619
# Lin similarity between finances and korean is 0.056737945084897254
# Lin similarity between finances and england is 0
# Lin similarity between finances and proposals is 0.2416935968076257
# Lin similarity between finances and weekend is 0.0609328909188182
# Lin similarity between finances and weak is 0
# Lin similarity between finances and millions is 0.06893900560148475
# Lin similarity between finances and changed is 0
# Lin similarity between finances and improve is 0
# Lin similarity between finances and begin is 0
# Lin similarity between finances and accord is 0.22970053810653385
# Lin similarity between finances and estimate is 0.2805298252895137
# Lin similarity between finances and losses is 0.5968256096671759
# Lin similarity between finances and push is 0.2661655827061844
# Lin similarity between finances and philippine is 0.056737945084897254
# Lin similarity between household and canadian is 0
# Lin similarity between household and beijing is 0
# Lin similarity between household and circulation is 0.06313445084698667
# Lin similarity between household and times is 0.09340239652518
# Lin similarity between household and area is 0.08406898120148881
# Lin similarity between household and life is 0.08520374573569604
# Lin similarity between household and organisation is 0.7038211478618049
# Lin similarity between household and agreements is 0.08327598238148638
# Lin similarity between household and trust is 0.45994675131801577
# Lin similarity between household and launched is 0
# Lin similarity between household and bids is 0.0823600672638935
# Lin similarity between household and rule is 0.0786483024606722
# Lin similarity between household and zealand is 0
# Lin similarity between household and executive is 0.37501578064453434
# Lin similarity between household and buy is 0.07324550899434197
# Lin similarity between household and limit is 0.07485571664362267
# Lin similarity between household and pilots is 0.0717623635988854
# Lin similarity between household and enough is 0.06748030281768136
# Lin similarity between household and though is 0
# Lin similarity between household and dtp is 0
# Lin similarity between household and peace is 0.07138604016048998
# Lin similarity between household and cooperation is 0.08022801092781756
# Lin similarity between household and unit is 0.7955897499903809
# Lin similarity between household and near is 0
# Lin similarity between household and finnish is 0.055052995606035174
# Lin similarity between household and socialist is 0
# Lin similarity between household and targets is 0.0845206921078049
# Lin similarity between household and stg is 0
# Lin similarity between household and hoped is 0
# Lin similarity between household and standard is 0.08962610446771618
# Lin similarity between household and lost is 0.3472483210614897
# Lin similarity between household and philippines is 0.06089952791665493
# Lin similarity between household and problem is 0.08103084956074884
# Lin similarity between household and francs is 0.0588174251899108
# Lin similarity between household and gordon is 0
# Lin similarity between household and included is 0
# Lin similarity between household and corporation is 0.47708909503020025
# Lin similarity between household and passed is 0
# Lin similarity between household and federation is 0.6009473802290095
# Lin similarity between household and benefit is 0.07898253961078298
# Lin similarity between household and nine is 0.5889541669710019
# Lin similarity between household and stearns is 0
# Lin similarity between household and communist is 0
# Lin similarity between household and fuel is 0
# Lin similarity between household and mortgage is 0.06421718229652969
# Lin similarity between household and whose is 0
# Lin similarity between household and probably is 0
# Lin similarity between household and elections is 0.07346865596879464
# Lin similarity between household and forced is 0
# Lin similarity between household and refunding is 0
# Lin similarity between household and suggested is 0
# Lin similarity between household and release is 0.0786483024606722
# Lin similarity between household and program is 0.0892148570037797
# Lin similarity between household and accounts is 0.08514928227438906
# Lin similarity between household and review is 0.07255848577750242
# Lin similarity between household and steady is 0
# Lin similarity between household and create is 0
# Lin similarity between household and abroad is 0
# Lin similarity between household and assembly is 0.474162432062154
# Lin similarity between household and personal is 0.07221463758718041
# Lin similarity between household and concerns is 0.5703180766812552
# Lin similarity between household and falls is 0.07813457964618695
# Lin similarity between household and approval is 0.08495085623905418
# Lin similarity between household and media is 0.07366347069626494
# Lin similarity between household and raising is 0.06875850920184835
# Lin similarity between household and selling is 0.07719383974693815
# Lin similarity between household and exchequer is 0.06518696936429223
# Lin similarity between household and limited is 0
# Lin similarity between household and found is 0.07758110014003833
# Lin similarity between household and try is 0.0901945432446083
# Lin similarity between household and fixed is 0
# Lin similarity between household and sold is 0
# Lin similarity between household and airways is 0.4107684742167863
# Lin similarity between household and paris is 0.327151202080632
# Lin similarity between household and civil is 0
# Lin similarity between household and joint is 0.07074314026241685
# Lin similarity between household and reduction is 0.08138711184418788
# Lin similarity between household and addition is 0.07717377607637738
# Lin similarity between household and means is 0.08524928798092511
# Lin similarity between household and believe is 0
# Lin similarity between household and signs is 0.10189898958721089
# Lin similarity between household and human is 0
# Lin similarity between household and summer is 0.07192675925832355
# Lin similarity between household and korean is 0.06089952791665493
# Lin similarity between household and england is 0
# Lin similarity between household and proposals is 0.08309247907506587
# Lin similarity between household and weekend is 0.06575877051933514
# Lin similarity between household and weak is 0
# Lin similarity between household and millions is 0.07518132528888935
# Lin similarity between household and changed is 0
# Lin similarity between household and improve is 0
# Lin similarity between household and begin is 0
# Lin similarity between household and accord is 0.0762125865115347
# Lin similarity between household and estimate is 0.07892313581657368
# Lin similarity between household and losses is 0.0786483024606722
# Lin similarity between household and push is 0.07923577479053391
# Lin similarity between household and philippine is 0.06089952791665493
# Lin similarity between canadian and beijing is 0.1007872117669583
# Lin similarity between canadian and circulation is 0.06817808897641753
# Lin similarity between canadian and times is 0
# Lin similarity between canadian and area is 0.4103555885154562
# Lin similarity between canadian and life is 0.23708274164048995
# Lin similarity between canadian and organisation is 0
# Lin similarity between canadian and agreements is 0
# Lin similarity between canadian and trust is 0
# Lin similarity between canadian and launched is 0
# Lin similarity between canadian and bids is 0
# Lin similarity between canadian and rule is 0.144311483403462
# Lin similarity between canadian and zealand is 2.580051361929983e-300
# Lin similarity between canadian and executive is 0.23398035002845696
# Lin similarity between canadian and buy is 0
# Lin similarity between canadian and limit is 0.13182411604382177
# Lin similarity between canadian and pilots is 0.21895383482036657
# Lin similarity between canadian and enough is 0
# Lin similarity between canadian and though is 0
# Lin similarity between canadian and dtp is 0
# Lin similarity between canadian and peace is 0
# Lin similarity between canadian and cooperation is 0
# Lin similarity between canadian and unit is 0.4141693920961061
# Lin similarity between canadian and near is 0
# Lin similarity between canadian and finnish is 0
# Lin similarity between canadian and socialist is 0.23050619183394241
# Lin similarity between canadian and targets is 0.2131316031608947
# Lin similarity between canadian and stg is 0
# Lin similarity between canadian and hoped is 0
# Lin similarity between canadian and standard is 0.14516478589842916
# Lin similarity between canadian and lost is 0
# Lin similarity between canadian and philippines is 0.10359219039258072
# Lin similarity between canadian and problem is 0
# Lin similarity between canadian and francs is 0
# Lin similarity between canadian and gordon is 0
# Lin similarity between canadian and included is 0
# Lin similarity between canadian and corporation is 0.3685756286170187
# Lin similarity between canadian and passed is 0
# Lin similarity between canadian and federation is 0
# Lin similarity between canadian and benefit is 0
# Lin similarity between canadian and nine is 0.07400681553480633
# Lin similarity between canadian and stearns is 0
# Lin similarity between canadian and communist is 0.22302653912268774
# Lin similarity between canadian and fuel is 0.08160541104566105
# Lin similarity between canadian and mortgage is 0
# Lin similarity between canadian and whose is 0
# Lin similarity between canadian and probably is 0
# Lin similarity between canadian and elections is 0
# Lin similarity between canadian and forced is 0
# Lin similarity between canadian and refunding is 0
# Lin similarity between canadian and suggested is 0
# Lin similarity between canadian and release is 0.138611884800975
# Lin similarity between canadian and program is 0
# Lin similarity between canadian and accounts is 0
# Lin similarity between canadian and review is 0.13822090526800881
# Lin similarity between canadian and steady is 0.2092569309385346
# Lin similarity between canadian and create is 0
# Lin similarity between canadian and abroad is 0
# Lin similarity between canadian and assembly is 0.13651493553941246
# Lin similarity between canadian and personal is 0.14489091913876223
# Lin similarity between canadian and concerns is 0
# Lin similarity between canadian and falls is 0.5520757082469557
# Lin similarity between canadian and approval is 0
# Lin similarity between canadian and media is 0.2174397932367668
# Lin similarity between canadian and raising is 0
# Lin similarity between canadian and selling is 0
# Lin similarity between canadian and exchequer is 0
# Lin similarity between canadian and limited is 0.1442683363455299
# Lin similarity between canadian and found is 0
# Lin similarity between canadian and try is 0
# Lin similarity between canadian and fixed is 0
# Lin similarity between canadian and sold is 0
# Lin similarity between canadian and airways is 0.3244966550262491
# Lin similarity between canadian and paris is 0.11681073986738426
# Lin similarity between canadian and civil is 0
# Lin similarity between canadian and joint is 0.38657453791093943
# Lin similarity between canadian and reduction is 0.07305875722855615
# Lin similarity between canadian and addition is 0.12553559150711852
# Lin similarity between canadian and means is 0.14835993020426294
# Lin similarity between canadian and believe is 0
# Lin similarity between canadian and signs is 0.14452357724601714
# Lin similarity between canadian and human is 0.25035219504556566
# Lin similarity between canadian and summer is 0
# Lin similarity between canadian and korean is 0.5088401041545146
# Lin similarity between canadian and england is 0.11896779896188056
# Lin similarity between canadian and proposals is 0
# Lin similarity between canadian and weekend is 0
# Lin similarity between canadian and weak is 0
# Lin similarity between canadian and millions is 0
# Lin similarity between canadian and changed is 0
# Lin similarity between canadian and improve is 0
# Lin similarity between canadian and begin is 0.21814641746758653
# Lin similarity between canadian and accord is 0
# Lin similarity between canadian and estimate is 0
# Lin similarity between canadian and losses is 0.0755323792306948
# Lin similarity between canadian and push is 0.14133248973557838
# Lin similarity between canadian and philippine is 0
# Lin similarity between beijing and circulation is 0.06296834939806689
# Lin similarity between beijing and times is 0
# Lin similarity between beijing and area is 0.5597015924177696
# Lin similarity between beijing and life is 0.11941337071139672
# Lin similarity between beijing and organisation is 0
# Lin similarity between beijing and agreements is 0
# Lin similarity between beijing and trust is 0
# Lin similarity between beijing and launched is 0
# Lin similarity between beijing and bids is 0
# Lin similarity between beijing and rule is 0.11132687885024468
# Lin similarity between beijing and zealand is 2.580051361929983e-300
# Lin similarity between beijing and executive is 0.1178513750320397
# Lin similarity between beijing and buy is 0
# Lin similarity between beijing and limit is 0.27991538312341346
# Lin similarity between beijing and pilots is 0.11091595333320653
# Lin similarity between beijing and enough is 0
# Lin similarity between beijing and though is 0
# Lin similarity between beijing and dtp is 0
# Lin similarity between beijing and peace is 0
# Lin similarity between beijing and cooperation is 0
# Lin similarity between beijing and unit is 0.16858357728880952
# Lin similarity between beijing and near is 0
# Lin similarity between beijing and finnish is 0
# Lin similarity between beijing and socialist is 0.11625493891794673
# Lin similarity between beijing and targets is 0.25077174077334163
# Lin similarity between beijing and stg is 0
# Lin similarity between beijing and hoped is 0
# Lin similarity between beijing and standard is 0.111929575828309
# Lin similarity between beijing and lost is 0
# Lin similarity between beijing and philippines is 0.32691847729670054
# Lin similarity between beijing and problem is 0
# Lin similarity between beijing and francs is 0
# Lin similarity between beijing and gordon is 0
# Lin similarity between beijing and included is 0
# Lin similarity between beijing and corporation is 0.06901570503589544
# Lin similarity between beijing and passed is 0
# Lin similarity between beijing and federation is 0
# Lin similarity between beijing and benefit is 0
# Lin similarity between beijing and nine is 0.06790805101652556
# Lin similarity between beijing and stearns is 0
# Lin similarity between beijing and communist is 0.11280354659552982
# Lin similarity between beijing and fuel is 0.07425219795010103
# Lin similarity between beijing and mortgage is 0
# Lin similarity between beijing and whose is 0
# Lin similarity between beijing and probably is 0
# Lin similarity between beijing and elections is 0
# Lin similarity between beijing and forced is 0
# Lin similarity between beijing and refunding is 0
# Lin similarity between beijing and suggested is 0
# Lin similarity between beijing and release is 0.10728578977605668
# Lin similarity between beijing and program is 0
# Lin similarity between beijing and accounts is 0
# Lin similarity between beijing and review is 0.10700759440401203
# Lin similarity between beijing and steady is 0.10639795715849978
# Lin similarity between beijing and create is 0
# Lin similarity between beijing and abroad is 0
# Lin similarity between beijing and assembly is 0.105792250596781
# Lin similarity between beijing and personal is 0.1117362059017519
# Lin similarity between beijing and concerns is 0
# Lin similarity between beijing and falls is 0.11271056520320469
# Lin similarity between beijing and approval is 0
# Lin similarity between beijing and media is 0.39593813665669236
# Lin similarity between beijing and raising is 0
# Lin similarity between beijing and selling is 0
# Lin similarity between beijing and exchequer is 0
# Lin similarity between beijing and limited is 0.1112963877109885
# Lin similarity between beijing and found is 0
# Lin similarity between beijing and try is 0
# Lin similarity between beijing and fixed is 0
# Lin similarity between beijing and sold is 0
# Lin similarity between beijing and airways is 0.2596796313329603
# Lin similarity between beijing and paris is 0.6453593501003759
# Lin similarity between beijing and civil is 0
# Lin similarity between beijing and joint is 0.11201034184700998
# Lin similarity between beijing and reduction is 0.06710896622499864
# Lin similarity between beijing and addition is 0.3719986907713462
# Lin similarity between beijing and means is 0.11418103823986385
# Lin similarity between beijing and believe is 0
# Lin similarity between beijing and signs is 0.2818644559763936
# Lin similarity between beijing and human is 0.13087351977314993
# Lin similarity between beijing and summer is 0
# Lin similarity between beijing and korean is 0.09947965490501608
# Lin similarity between beijing and england is 0.37144584229642136
# Lin similarity between beijing and proposals is 0
# Lin similarity between beijing and weekend is 0
# Lin similarity between beijing and weak is 0
# Lin similarity between beijing and millions is 0
# Lin similarity between beijing and changed is 0
# Lin similarity between beijing and improve is 0
# Lin similarity between beijing and begin is 0.11054103829283739
# Lin similarity between beijing and accord is 0
# Lin similarity between beijing and estimate is 0
# Lin similarity between beijing and losses is 0.06919035890106004
# Lin similarity between beijing and push is 0.10921808299964805
# Lin similarity between beijing and philippine is 0
# Lin similarity between circulation and times is 0.4297074425874452
# Lin similarity between circulation and area is 0.16093423270477106
# Lin similarity between circulation and life is 0.7584631281657147
# Lin similarity between circulation and organisation is 0.4088448495990958
# Lin similarity between circulation and agreements is 0.2398573827125085
# Lin similarity between circulation and trust is 0.15240859713339847
# Lin similarity between circulation and launched is 0
# Lin similarity between circulation and bids is 0.24579600573828403
# Lin similarity between circulation and rule is 0.2540948339408717
# Lin similarity between circulation and zealand is 1.6035182299077988e-300
# Lin similarity between circulation and executive is 0.08093273477117632
# Lin similarity between circulation and buy is 0.05738846158250641
# Lin similarity between circulation and limit is 0.26346538551772863
# Lin similarity between circulation and pilots is 0.18354952444285585
# Lin similarity between circulation and enough is 0.24277384535162636
# Lin similarity between circulation and though is 0
# Lin similarity between circulation and dtp is 0
# Lin similarity between circulation and peace is 0.05624065279316706
# Lin similarity between circulation and cooperation is 0.2409114105671311
# Lin similarity between circulation and unit is 0.4540629614717465
# Lin similarity between circulation and near is 0
# Lin similarity between circulation and finnish is 0.04558569302704474
# Lin similarity between circulation and socialist is 0.07972306142725881
# Lin similarity between circulation and targets is 0.17120046420944443
# Lin similarity between circulation and stg is 0
# Lin similarity between circulation and hoped is 0
# Lin similarity between circulation and standard is 0.34500172605371593
# Lin similarity between circulation and lost is 0.056936444825457816
# Lin similarity between circulation and philippines is 0.06473024895324397
# Lin similarity between circulation and problem is 0.16536996141252677
# Lin similarity between circulation and francs is 0.2928649002115586
# Lin similarity between circulation and gordon is 0
# Lin similarity between circulation and included is 0
# Lin similarity between circulation and corporation is 0.07579974654403324
# Lin similarity between circulation and passed is 0
# Lin similarity between circulation and federation is 0.34508920372861607
# Lin similarity between circulation and benefit is 0.18832207754622995
# Lin similarity between circulation and nine is 0.41593400282192516
# Lin similarity between circulation and stearns is 0
# Lin similarity between circulation and communist is 0.07711952924940561
# Lin similarity between circulation and fuel is 0.08216376392421992
# Lin similarity between circulation and mortgage is 0.051694152680816625
# Lin similarity between circulation and whose is 0
# Lin similarity between circulation and probably is 0
# Lin similarity between circulation and elections is 0.3498577619113578
# Lin similarity between circulation and forced is 0
# Lin similarity between circulation and refunding is 0
# Lin similarity between circulation and suggested is 0
# Lin similarity between circulation and release is 0.4123521198160349
# Lin similarity between circulation and program is 0.23748738860309496
# Lin similarity between circulation and accounts is 0.24130883986448293
# Lin similarity between circulation and review is 0.22283025458498817
# Lin similarity between circulation and steady is 0.07232950855518766
# Lin similarity between circulation and create is 0
# Lin similarity between circulation and abroad is 0
# Lin similarity between circulation and assembly is 0.24656332726178076
# Lin similarity between circulation and personal is 0.07631761121356889
# Lin similarity between circulation and concerns is 0.16266264923000195
# Lin similarity between circulation and falls is 0.6109734336167717
# Lin similarity between circulation and approval is 0.2258021893827455
# Lin similarity between circulation and media is 0.7387033556457409
# Lin similarity between circulation and raising is 0.5816435198774765
# Lin similarity between circulation and selling is 0.23385512578915776
# Lin similarity between circulation and exchequer is 0.052320737152067476
# Lin similarity between circulation and limited is 0.0759876064707776
# Lin similarity between circulation and found is 0.06001634131179795
# Lin similarity between circulation and try is 0.26324147085926625
# Lin similarity between circulation and fixed is 0
# Lin similarity between circulation and sold is 0
# Lin similarity between circulation and airways is 0.07594146842455657
# Lin similarity between circulation and paris is 0.1450998248656647
# Lin similarity between circulation and civil is 0
# Lin similarity between circulation and joint is 0.07957015210609093
# Lin similarity between circulation and reduction is 0.694512020787945
# Lin similarity between circulation and addition is 0.68499437578681
# Lin similarity between circulation and means is 0.2523204105111653
# Lin similarity between circulation and believe is 0
# Lin similarity between circulation and signs is 0.3853013534882476
# Lin similarity between circulation and human is 0.09093001873060573
# Lin similarity between circulation and summer is 0.25535668352029306
# Lin similarity between circulation and korean is 0.06721648564500003
# Lin similarity between circulation and england is 0.07439731948212117
# Lin similarity between circulation and proposals is 0.21876013014746293
# Lin similarity between circulation and weekend is 0.23781132998091303
# Lin similarity between circulation and weak is 0
# Lin similarity between circulation and millions is 0.4232938145920161
# Lin similarity between circulation and changed is 0
# Lin similarity between circulation and improve is 0
# Lin similarity between circulation and begin is 0.07542145141324597
# Lin similarity between circulation and accord is 0.2088885731279477
# Lin similarity between circulation and estimate is 0.21382154753779528
# Lin similarity between circulation and losses is 0.4123521198160349
# Lin similarity between circulation and push is 0.45335154996005217
# Lin similarity between circulation and philippine is 0.04952240619075322
# Lin similarity between times and area is 0.743589263508217
# Lin similarity between times and life is 0.9236675284867202
# Lin similarity between times and organisation is 0.3872598876203233
# Lin similarity between times and agreements is 0.3374936469471591
# Lin similarity between times and trust is 0.33608863319348614
# Lin similarity between times and launched is 0
# Lin similarity between times and bids is 0.3532218858249854
# Lin similarity between times and rule is 0.7472669012717194
# Lin similarity between times and zealand is 0
# Lin similarity between times and executive is 0.07376015923488122
# Lin similarity between times and buy is 0.08135203054128458
# Lin similarity between times and limit is 0.6565692304662318
# Lin similarity between times and pilots is 0.3315781910420406
# Lin similarity between times and enough is 0.3234315410455094
# Lin similarity between times and though is 0
# Lin similarity between times and dtp is 0
# Lin similarity between times and peace is 0.30479711474078913
# Lin similarity between times and cooperation is 0.31514748414219446
# Lin similarity between times and unit is 0.5150855936698449
# Lin similarity between times and near is 0
# Lin similarity between times and finnish is 0.05951014406225331
# Lin similarity between times and socialist is 0
# Lin similarity between times and targets is 0.39344711716360153
# Lin similarity between times and stg is 0
# Lin similarity between times and hoped is 0
# Lin similarity between times and standard is 0.4384850906333534
# Lin similarity between times and lost is 0.08044668131098255
# Lin similarity between times and philippines is 0.06640092783481104
# Lin similarity between times and problem is 0.37513975203699385
# Lin similarity between times and francs is 0.2796876190712395
# Lin similarity between times and gordon is 0
# Lin similarity between times and included is 0
# Lin similarity between times and corporation is 0.08081889711198327
# Lin similarity between times and passed is 0
# Lin similarity between times and federation is 0.22306399832157045
# Lin similarity between times and benefit is 0.3411366775265983
# Lin similarity between times and nine is 0.3489066280318403
# Lin similarity between times and stearns is 0
# Lin similarity between times and communist is 0
# Lin similarity between times and fuel is 0
# Lin similarity between times and mortgage is 0.07036456724599088
# Lin similarity between times and whose is 0
# Lin similarity between times and probably is 0
# Lin similarity between times and elections is 0.32684004310783266
# Lin similarity between times and forced is 0
# Lin similarity between times and refunding is 0
# Lin similarity between times and suggested is 0
# Lin similarity between times and release is 0.5354469942798354
# Lin similarity between times and program is 0.4164439085490191
# Lin similarity between times and accounts is 0.3015968581178103
# Lin similarity between times and review is 0.3444928756378101
# Lin similarity between times and steady is 0
# Lin similarity between times and create is 0
# Lin similarity between times and abroad is 0
# Lin similarity between times and assembly is 0.31927380336336825
# Lin similarity between times and personal is 0.08008232410109331
# Lin similarity between times and concerns is 0.7047493893937512
# Lin similarity between times and falls is 0.894623798015739
# Lin similarity between times and approval is 0.34977319638746435
# Lin similarity between times and media is 0.325986075677879
# Lin similarity between times and raising is 0.4680331981499333
# Lin similarity between times and selling is 0.2701964809448166
# Lin similarity between times and exchequer is 0.07153059861097841
# Lin similarity between times and limited is 0
# Lin similarity between times and found is 0.0867356905244131
# Lin similarity between times and try is 0.41811451986499776
# Lin similarity between times and fixed is 0
# Lin similarity between times and sold is 0
# Lin similarity between times and airways is 0.06853664482828059
# Lin similarity between times and paris is 0.31501428766368217
# Lin similarity between times and civil is 0
# Lin similarity between times and joint is 0.30175980364294824
# Lin similarity between times and reduction is 0.28325558426443026
# Lin similarity between times and addition is 0.8913270751522926
# Lin similarity between times and means is 0.8294687423099306
# Lin similarity between times and believe is 0
# Lin similarity between times and signs is 0.8087110243827391
# Lin similarity between times and human is 0
# Lin similarity between times and summer is 0.4888403405004361
# Lin similarity between times and korean is 0.06640092783481104
# Lin similarity between times and england is 0
# Lin similarity between times and proposals is 0.2502455154616536
# Lin similarity between times and weekend is 0.44439533011005744
# Lin similarity between times and weak is 0
# Lin similarity between times and millions is 0.36290647744410226
# Lin similarity between times and changed is 0
# Lin similarity between times and improve is 0
# Lin similarity between times and begin is 0
# Lin similarity between times and accord is 0.32778891105845365
# Lin similarity between times and estimate is 0.36618940005480694
# Lin similarity between times and losses is 0.7955296700495704
# Lin similarity between times and push is 0.30362972527029947
# Lin similarity between times and philippine is 0.06640092783481104
# Lin similarity between area and life is 0.4276129693800305
# Lin similarity between area and organisation is 0.34728897780092965
# Lin similarity between area and agreements is 0.40291985697382837
# Lin similarity between area and trust is 0.3804137039124281
# Lin similarity between area and launched is 0
# Lin similarity between area and bids is 0.20705487879435566
# Lin similarity between area and rule is 0.39374518504685363
# Lin similarity between area and zealand is 2.580051361929983e-300
# Lin similarity between area and executive is 0.23100969867266907
# Lin similarity between area and buy is 0.07417909819872356
# Lin similarity between area and limit is 0.8059226717555266
# Lin similarity between area and pilots is 0.516195623219508
# Lin similarity between area and enough is 0.06827191483226998
# Lin similarity between area and though is 0
# Lin similarity between area and dtp is 0
# Lin similarity between area and peace is 0.3773098542646169
# Lin similarity between area and cooperation is 0.20200287935271471
# Lin similarity between area and unit is 0.5525417923429606
# Lin similarity between area and near is 0
# Lin similarity between area and finnish is 0.055578750109730075
# Lin similarity between area and socialist is 0.22588913515412445
# Lin similarity between area and targets is 0.43854003242807155
# Lin similarity between area and stg is 0
# Lin similarity between area and hoped is 0
# Lin similarity between area and standard is 0.3987741829902462
# Lin similarity between area and lost is 0.07342562328462911
# Lin similarity between area and philippines is 0.39038602369609904
# Lin similarity between area and problem is 0.42282918716132306
# Lin similarity between area and francs is 0.05941793042820877
# Lin similarity between area and gordon is 0
# Lin similarity between area and included is 0
# Lin similarity between area and corporation is 0.5262287052449576
# Lin similarity between area and passed is 0
# Lin similarity between area and federation is 0.15926354388986386
# Lin similarity between area and benefit is 0.308669791405185
# Lin similarity between area and nine is 0.10702438939062058
# Lin similarity between area and stearns is 0
# Lin similarity between area and communist is 0.21511900363825381
# Lin similarity between area and fuel is 0.1236784191805579
# Lin similarity between area and mortgage is 0.06493367954954218
# Lin similarity between area and whose is 0
# Lin similarity between area and probably is 0
# Lin similarity between area and elections is 0.37408135382520274
# Lin similarity between area and forced is 0
# Lin similarity between area and refunding is 0
# Lin similarity between area and suggested is 0
# Lin similarity between area and release is 0.2991102041277138
# Lin similarity between area and program is 0.46134941917052646
# Lin similarity between area and accounts is 0.3737163972601874
# Lin similarity between area and review is 0.2979022078631274
# Lin similarity between area and steady is 0.1961534904865869
# Lin similarity between area and create is 0
# Lin similarity between area and abroad is 0
# Lin similarity between area and assembly is 0.2926656759941777
# Lin similarity between area and personal is 0.3189231627167235
# Lin similarity between area and concerns is 0.4593746505353398
# Lin similarity between area and falls is 0.6558130292849642
# Lin similarity between area and approval is 0.666687407445032
# Lin similarity between area and media is 0.45996464377694996
# Lin similarity between area and raising is 0.26173483362751226
# Lin similarity between area and selling is 0.19478661574364203
# Lin similarity between area and exchequer is 0.06592539506199982
# Lin similarity between area and limited is 0.3169232735100032
# Lin similarity between area and found is 0.07862927435535226
# Lin similarity between area and try is 0.22548741430547506
# Lin similarity between area and fixed is 0
# Lin similarity between area and sold is 0
# Lin similarity between area and airways is 0.4479334078344104
# Lin similarity between area and paris is 0.6855858178175277
# Lin similarity between area and civil is 0
# Lin similarity between area and joint is 0.5597653762226131
# Lin similarity between area and reduction is 0.20475133155852987
# Lin similarity between area and addition is 0.48616009226174856
# Lin similarity between area and means is 0.3302135723175694
# Lin similarity between area and believe is 0
# Lin similarity between area and signs is 0.5483501934369055
# Lin similarity between area and human is 0.27641100503552724
# Lin similarity between area and summer is 0.07282682690601384
# Lin similarity between area and korean is 0.1770381674144057
# Lin similarity between area and england is 0.4729898497988436
# Lin similarity between area and proposals is 0.1796660853815711
# Lin similarity between area and weekend is 0.06651028221839744
# Lin similarity between area and weak is 0
# Lin similarity between area and millions is 0.07616524598704089
# Lin similarity between area and changed is 0
# Lin similarity between area and improve is 0
# Lin similarity between area and begin is 0.20827292007729162
# Lin similarity between area and accord is 0.40291985697382837
# Lin similarity between area and estimate is 0.3302478885552526
# Lin similarity between area and losses is 0.2770014743458982
# Lin similarity between area and push is 0.3075984749739067
# Lin similarity between area and philippine is 0.061543533487175686
# Lin similarity between life and organisation is 0.3573213644090852
# Lin similarity between life and agreements is 0.3923966039424423
# Lin similarity between life and trust is 0.6207771021605261
# Lin similarity between life and launched is 0
# Lin similarity between life and bids is 0.30032772961107024
# Lin similarity between life and rule is 0.4665996284609836
# ...
# Lin similarity between airways and begin is 0.15001474698315956
# Lin similarity between airways and accord is 0.058804284759101065
# Lin similarity between airways and estimate is 0.06040497750537374
# Lin similarity between airways and losses is 0.08517943825720269
# Lin similarity between airways and push is 0.22273178047532635
# Lin similarity between airways and philippine is 0.04924929350179278
# Lin similarity between paris and civil is 0
# Lin similarity between paris and joint is 0.13215783292371563
# Lin similarity between paris and reduction is 0.17978944368462524
# Lin similarity between paris and addition is 0.4382767990559434
# Lin similarity between paris and means is 0.28622734085587964
# Lin similarity between paris and believe is 0
# Lin similarity between paris and signs is 0.33729104123518683
# Lin similarity between paris and human is 0.15923749206605625
# Lin similarity between paris and summer is 0.06070003427324179
# Lin similarity between paris and korean is 0.11505798802026314
# Lin similarity between paris and england is 0.4362700113833921
# Lin similarity between paris and proposals is 0.1601545321485133
# Lin similarity between paris and weekend is 0.05624764930524681
# Lin similarity between paris and weak is 0
# Lin similarity between paris and millions is 0.06300165363326522
# Lin similarity between paris and changed is 0
# Lin similarity between paris and improve is 0
# Lin similarity between paris and begin is 0.13011723425485525
# Lin similarity between paris and accord is 0.15243229888353177
# Lin similarity between paris and estimate is 0.2909995867635532
# Lin similarity between paris and losses is 0.17475698907650283
# Lin similarity between paris and push is 0.17584140719540692
# Lin similarity between paris and philippine is 0.052653992063775086
# Lin similarity between civil and joint is 0
# Lin similarity between civil and reduction is 0
# Lin similarity between civil and addition is 0
# Lin similarity between civil and means is 0
# Lin similarity between civil and believe is 0
# Lin similarity between civil and signs is 0
# Lin similarity between civil and human is 0
# Lin similarity between civil and summer is 0
# Lin similarity between civil and korean is 0
# Lin similarity between civil and england is 0
# Lin similarity between civil and proposals is 0
# Lin similarity between civil and weekend is 0
# Lin similarity between civil and weak is 0
# Lin similarity between civil and millions is 0
# Lin similarity between civil and changed is 0
# Lin similarity between civil and improve is 0
# Lin similarity between civil and begin is 0
# Lin similarity between civil and accord is 0
# Lin similarity between civil and estimate is 0
# Lin similarity between civil and losses is 0
# Lin similarity between civil and push is 0
# Lin similarity between civil and philippine is 0
# Lin similarity between joint and reduction is 0.0862986206635662
# Lin similarity between joint and addition is 0.3125662036754407
# Lin similarity between joint and means is 0.3602573952790294
# Lin similarity between joint and believe is 0
# Lin similarity between joint and signs is 0.39687972498323115
# Lin similarity between joint and human is 0.20151434296690404
# Lin similarity between joint and summer is 0.0626101301907838
# Lin similarity between joint and korean is 0.2060962352019347
# Lin similarity between joint and england is 0.13492564925078315
# Lin similarity between joint and proposals is 0.07090384094728855
# Lin similarity between joint and weekend is 0.05788403164050826
# Lin similarity between joint and weak is 0
# Lin similarity between joint and millions is 0.06506180773798122
# Lin similarity between joint and changed is 0
# Lin similarity between joint and improve is 0
# Lin similarity between joint and begin is 0.23344700170000396
# Lin similarity between joint and accord is 0.25378762035110874
# Lin similarity between joint and estimate is 0.06784545611391411
# Lin similarity between joint and losses is 0.3247452846064571
# Lin similarity between joint and push is 0.34090274668604215
# Lin similarity between joint and philippine is 0.05408529695499668
# Lin similarity between reduction and addition is 0.7867289216924896
# Lin similarity between reduction and means is 0.32732237648426976
# Lin similarity between reduction and believe is 0
# Lin similarity between reduction and signs is 0.24235215350619782
# Lin similarity between reduction and human is 0.09982418487430843
# Lin similarity between reduction and summer is 0.07080564470041555
# Lin similarity between reduction and korean is 0.07195566304874557
# Lin similarity between reduction and england is 0.08024723436146004
# Lin similarity between reduction and proposals is 0.2729932597286865
# Lin similarity between reduction and weekend is 0.06482043694435413
# Lin similarity between reduction and weak is 0
# Lin similarity between reduction and millions is 0.07395732148226151
# Lin similarity between reduction and changed is 0
# Lin similarity between reduction and improve is 0
# Lin similarity between reduction and begin is 0.08144004585842501
# Lin similarity between reduction and accord is 0.2577905263321216
# Lin similarity between reduction and estimate is 0.2653452929369694
# Lin similarity between reduction and losses is 0.4188284326448784
# Lin similarity between reduction and push is 0.4525583472367815
# Lin similarity between reduction and philippine is 0.06009389738890967
# Lin similarity between addition and means is 0.49465764702550347
# Lin similarity between addition and believe is 0
# Lin similarity between addition and signs is 0.3533708246072883
# Lin similarity between addition and human is 0.17590335707408444
# Lin similarity between addition and summer is 0.30509284813528864
# Lin similarity between addition and korean is 0.12351349367833617
# Lin similarity between addition and england is 0.447366979816984
# Lin similarity between addition and proposals is 0.24475202009451982
# Lin similarity between addition and weekend is 0.28037798079706894
# Lin similarity between addition and weak is 0
# Lin similarity between addition and millions is 0.6134956896322861
# Lin similarity between addition and changed is 0
# Lin similarity between addition and improve is 0
# Lin similarity between addition and begin is 0.1410359907312028
# Lin similarity between addition and accord is 0.23246123492768672
# Lin similarity between addition and estimate is 0.23858670599070858
# Lin similarity between addition and losses is 0.604166894940721
# Lin similarity between addition and push is 0.40746068954640063
# Lin similarity between addition and philippine is 0.0577652810301201
# Lin similarity between means and believe is 0
# Lin similarity between means and signs is 0.5775381956472959
# Lin similarity between means and human is 0.20749072497032442
# Lin similarity between means and summer is 0.07371090676906586
# Lin similarity between means and korean is 0.1459813295040338
# Lin similarity between means and england is 0.13808790604827695
# Lin similarity between means and proposals is 0.28402739382460945
# Lin similarity between means and weekend is 0.06724687808015642
# Lin similarity between means and weak is 0
# Lin similarity between means and millions is 0.07713277537270112
# Lin similarity between means and changed is 0
# Lin similarity between means and improve is 0
# Lin similarity between means and begin is 0.16658104685346214
# Lin similarity between means and accord is 0.26760782176956877
# Lin similarity between means and estimate is 0.3278587025479104
# Lin similarity between means and losses is 0.5968256096671759
# Lin similarity between means and push is 0.3488967526172214
# Lin similarity between means and philippine is 0.062173703190624645
# Lin similarity between believe and signs is 0
# Lin similarity between believe and human is 0
# Lin similarity between believe and summer is 0
# Lin similarity between believe and korean is 0
# Lin similarity between believe and england is 0
# Lin similarity between believe and proposals is 0
# Lin similarity between believe and weekend is 0
# Lin similarity between believe and weak is 0
# Lin similarity between believe and millions is 0
# Lin similarity between believe and changed is 0
# Lin similarity between believe and improve is 0
# Lin similarity between believe and begin is 0
# Lin similarity between believe and accord is 0
# Lin similarity between believe and estimate is 0
# Lin similarity between believe and losses is 0
# Lin similarity between believe and push is 0
# Lin similarity between believe and philippine is 0
# Lin similarity between signs and human is 0.20006344714263122
# Lin similarity between signs and summer is 0.08583801444154641
# Lin similarity between signs and korean is 0.3101285110554089
# Lin similarity between signs and england is 0.34502876122699555
# Lin similarity between signs and proposals is 0.4491785501460791
# Lin similarity between signs and weekend is 0.07719673606584752
# Lin similarity between signs and weak is 0
# Lin similarity between signs and millions is 0.09051416890320978
# Lin similarity between signs and changed is 0
# Lin similarity between signs and improve is 0
# Lin similarity between signs and begin is 0.16175979941973218
# Lin similarity between signs and accord is 0.433418362323363
# Lin similarity between signs and estimate is 0.4098959797412694
# Lin similarity between signs and losses is 0.7045129052238276
# Lin similarity between signs and push is 0.239913562861057
# Lin similarity between signs and philippine is 0.3101285110554089
# Lin similarity between human and summer is 0
# Lin similarity between human and korean is 0.2456994352113265
# Lin similarity between human and england is 0.16327310802340306
# Lin similarity between human and proposals is 0
# Lin similarity between human and weekend is 0
# Lin similarity between human and weak is 0
# Lin similarity between human and millions is 0
# Lin similarity between human and changed is 0
# Lin similarity between human and improve is 0
# Lin similarity between human and begin is 0.2868134069327325
# Lin similarity between human and accord is 0
# Lin similarity between human and estimate is 0
# Lin similarity between human and losses is 0.1045002549678979
# Lin similarity between human and push is 0.1939998932709535
# Lin similarity between human and philippine is 0
# Lin similarity between summer and korean is 0.05477441571262693
# Lin similarity between summer and england is 0
# Lin similarity between summer and proposals is 0.07209288867958617
# Lin similarity between summer and weekend is 0.37398918050716756
# Lin similarity between summer and weak is 0
# Lin similarity between summer and millions is 0.298171526525022
# Lin similarity between summer and changed is 0
# Lin similarity between summer and improve is 0
# Lin similarity between summer and begin is 0
# Lin similarity between summer and accord is 0.06685652875507313
# Lin similarity between summer and estimate is 0.0689333518185173
# Lin similarity between summer and losses is 0.06872359743942111
# Lin similarity between summer and push is 0.06917173496079317
# Lin similarity between summer and philippine is 0.05477441571262693
# Lin similarity between korean and england is 0.11715021945850537
# Lin similarity between korean and proposals is 0.26809647548150456
# Lin similarity between korean and weekend is 0.051122747319199344
# Lin similarity between korean and weak is 0
# Lin similarity between korean and millions is 0.056641683136655976
# Lin similarity between korean and changed is 0
# Lin similarity between korean and improve is 0
# Lin similarity between korean and begin is 0.21476870943729665
# Lin similarity between korean and accord is 0.2447197130926321
# Lin similarity between korean and estimate is 0.23317090583973676
# Lin similarity between korean and losses is 0.0743539258614367
# Lin similarity between korean and push is 0.1391722484553283
# Lin similarity between korean and philippine is 0.5186066018536329
# Lin similarity between england and proposals is 0
# Lin similarity between england and weekend is 0
# Lin similarity between england and weak is 0
# Lin similarity between england and millions is 0
# Lin similarity between england and changed is 0
# Lin similarity between england and improve is 0
# Lin similarity between england and begin is 0.13279936953227306
# Lin similarity between england and accord is 0
# Lin similarity between england and estimate is 0
# Lin similarity between england and losses is 0.08324155388759047
# Lin similarity between england and push is 0.13089458968083506
# Lin similarity between england and philippine is 0
# Lin similarity between proposals and weekend is 0.0658976016705653
# Lin similarity between proposals and weak is 0
# Lin similarity between proposals and millions is 0.07536284797554975
# Lin similarity between proposals and changed is 0
# Lin similarity between proposals and improve is 0
# Lin similarity between proposals and begin is 0
# Lin similarity between proposals and accord is 0.4916347776388263
# Lin similarity between proposals and estimate is 0.44028237777298374
# Lin similarity between proposals and losses is 0.2533479897930954
# Lin similarity between proposals and push is 0.266781990280221
# Lin similarity between proposals and philippine is 0.26809647548150456
# Lin similarity between weekend and weak is 0
# Lin similarity between weekend and millions is 0.2745218382962005
# Lin similarity between weekend and changed is 0
# Lin similarity between weekend and improve is 0
# Lin similarity between weekend and begin is 0
# Lin similarity between weekend and accord is 0.06149506376474699
# Lin similarity between weekend and estimate is 0.06324778087576839
# Lin similarity between weekend and losses is 0.06307115601252516
# Lin similarity between weekend and push is 0.06344840514954979
# Lin similarity between weekend and philippine is 0.051122747319199344
# Lin similarity between weak and millions is 0
# Lin similarity between weak and changed is 0
# Lin similarity between weak and improve is 0
# Lin similarity between weak and begin is 0
# Lin similarity between weak and accord is 0
# Lin similarity between weak and estimate is 0
# Lin similarity between weak and losses is 0
# Lin similarity between weak and push is 0
# Lin similarity between weak and philippine is 0
# Lin similarity between millions and changed is 0
# Lin similarity between millions and improve is 0
# Lin similarity between millions and begin is 0
# Lin similarity between millions and accord is 0.06965948756795398
# Lin similarity between millions and estimate is 0.07191704274682688
# Lin similarity between millions and losses is 0.07168876756878997
# Lin similarity between millions and push is 0.07217654754990271
# Lin similarity between millions and philippine is 0.056641683136655976
# Lin similarity between changed and improve is 0
# Lin similarity between changed and begin is 0
# Lin similarity between changed and accord is 0
# Lin similarity between changed and estimate is 0
# Lin similarity between changed and losses is 0
# Lin similarity between changed and push is 0
# Lin similarity between changed and philippine is 0
# Lin similarity between improve and begin is 0
# Lin similarity between improve and accord is 0
# Lin similarity between improve and estimate is 0
# Lin similarity between improve and losses is 0
# Lin similarity between improve and push is 0
# Lin similarity between improve and philippine is 0
# Lin similarity between begin and accord is 0
# Lin similarity between begin and estimate is 0
# Lin similarity between begin and losses is 0.08452575478569589
# Lin similarity between begin and push is 0.15777266960616798
# Lin similarity between begin and philippine is 0
# Lin similarity between accord and estimate is 0.5324856869340524
# Lin similarity between accord and losses is 0.3642380346059588
# Lin similarity between accord and push is 0.25510895819114904
# Lin similarity between accord and philippine is 0.2447197130926321
# Lin similarity between estimate and losses is 0.24674784427134785
# Lin similarity between estimate and push is 0.2594734259246993
# Lin similarity between estimate and philippine is 0.23317090583973676
# Lin similarity between losses and push is 0.4196499278570765
# Lin similarity between losses and philippine is 0.05858745738998506
# Lin similarity between push and philippine is 0.058912837758835816

# %% [markdown]
# 3. D Identify the 10 most similar words (according to WordNet) to the most frequent word in the corpus [20 marks]

# %%
import operator
#below creates seperate dictionary of words 
stop = stopwords.words('english')
dictwords = {}
def getdictwords(sentences):
  for sentence in sentences:
    for words in sentence:
        if words in dictwords:
          dictwords[words] += 1
        else:
          dictwords.update({words:1})
getdictwords(sentences)
dictwords 

#below normalises dictwords i.e removes stopwords numbers and punctuation
dictwords_stopremoval = {k: v for k,v in dictwords.items() if k not in stop and k.isalpha() and k != "NUM"} #removes number and stopwords
#below sorts order of words
sortedwords = dict(sorted(dictwords_stopremoval.items(), key=operator.itemgetter(1), reverse=True)) # sorts words order
sortedwords
def mostfreqword(freqdist,k=1): #identifies most frequent word
  return sorted(freqdist.items(),key=operator.itemgetter(1),reverse=True)[:k] #sorts the frequency of words into order and finds the single highest occuring word
mostfrequent = mostfreqword(sortedwords)

print("The synsets below are all similar words to 'said' the most frequently used word in the corpus:")
similarwords = [] 
synsets = wn.synsets("said")  
    #iterate over synsets
for synset in synsets:
  #iterates through synsets lemmas
  for l in synset.lemmas(): 
    #checks if similarwords list is no bigger than 10 long and that all words are unique
    if len(similarwords) < 10 and l.name() not in similarwords:
        similarwords.append(l.name()) 
print(similarwords)
# Out:
# The synsets below are all similar words to 'said' the most frequently used word in the corpus:
# ['state', 'say', 'tell', 'allege', 'aver', 'suppose', 'read', 'order', 'enjoin', 'pronounce']

# %% [markdown]
# 4)a) Write code to construct distributional vector representations of words in the corpus with a parameter to specify context size.  Explain how you calculate the value of association between each word and each context feature.
#
# b) Use your code to construct representations of the 1000 words identified in Q2 with a window size of 1
#
# c) Use your representations to find the 10 words which are distributionally most similar to the most frequent word in the corpus. [15 marks]

# %% [markdown]
# 4)a) Write code to construct distributional vector representations of words in the corpus with a parameter to specify context size. Explain how you calculate the value of association between each word and each context feature.
# >
# Using positive pointwise mutual information (PMI) is a way to value the association berween words. This is because PMI can determine the significance of a frequency of co-occurence. PMI can determine how common a co-occurence is and by doing so can establish whether it is insignificant or significant. If they are common words and common co-occurences they will be insignificant, whereas, if they are rare words then co-occurences will be determined as more important in the representation of each word. To calculate PMI you do the following:
# >
# \begin{eqnarray*}
# PMI(word,feat) = \frac{\mbox{freq}(word,feat) \times \Sigma_{w*,f*} \mbox{freq}(w*,f*)}{\Sigma_{f*} \mbox{freq}(word,f*) \times \Sigma_{w*} \mbox{freq}(w*,feat)}
# \end{eqnarray*}
# >

# %%
def dot(vecA,vecB):
    the_sum=0
    for (key,value) in vecA.items():
        the_sum+=value*vecB.get(key,0)
    return the_sum

# %%
class vectors:
    def __init__(self,sentences,window=3):
        self.sentences=sentences
        self.window=window
        self.reps={}
        self.wordtotals={}
        self.feattotals={}
        self.generate_features()
        self.grandtotal=sum(self.wordtotals.values())
        self.convert_to_ppmi()
    
    def generate_features(self):
        for sentence in self.sentences:
            for i,token in enumerate(sentence):
                current=self.reps.get(token,{})
                features=sentence[max(0,i-self.window):i]+sentence[i+1:i+self.window+1]
                for feature in features:
                    current[feature]=current.get(feature,0)+1
                    self.feattotals[feature]=self.feattotals.get(feature,0)+1
                self.wordtotals[token]=self.wordtotals.get(token,0)+len(features)
                self.reps[token]=current

    def convert_to_ppmi(self):
        self.ppmi={word:{feat:max(0,math.log((freq*self.grandtotal)/(self.wordtotals[word]*self.feattotals[feat]),2)) for (feat,freq) in rep.items()} for (word,rep) in self.reps.items()}
    
    def similarity(self,word1,word2):
        rep1=self.ppmi.get(word1,{})
        rep2=self.ppmi.get(word2,{})
        return dot(rep1,rep2)/math.sqrt(dot(rep1,rep1)*dot(rep2,rep2))
    
    def nearest_neighbours(self,word1,n=1000,k=10):
        candidates=sorted(self.wordtotals.items(),key=operator.itemgetter(1),reverse=True)[:n]
        sims=[(cand,self.similarity(word1,cand)) for (cand,_) in candidates]
        return sorted(sims,key=operator.itemgetter(1),reverse=True)[:k]

# %%
vcr=vectors(sentences,window=1)
vcr.convert_to_ppmi()
print(vcr.similarity('korea','germany'))
# Out:
# 0.03672634043661373

# %%
vcr.reps['said']

# %%
vcr.generate_features()

# %%
vcr.similarity("said", "say")
# Out:
# 0.034341937499454474

# %% [markdown]
# 4.C

# %%
vcr.nearest_neighbours("said")
# Out:
# [('said', 1.0),
#  ("''", 0.42742291973035473),
#  ('told', 0.22901210586530568),
#  (',', 0.19507157818399515),
#  ('added', 0.1416384654932068),
#  ("'s", 0.11012275321283063),
#  ('but', 0.096675436568098),
#  ('says', 0.08836968511984952),
#  ('noted', 0.08819544901156108),
#  ('.', 0.08223991888292137)]

# %% [markdown]
# 5) Plan and carry out an investigation into the correlation between semantic similarity according to WordNet and distributional similarity with different context window sizes. You should make sure that you include a graph of how correlation varies with context window size and that you discuss your results. [25 marks]

# %%
vcr=vectors(sentences,window=1)
vcr.nearest_neighbours('said')
# Out:
# [('said', 1.0),
#  ("''", 0.42742291973035473),
#  ('told', 0.22901210586530568),
#  (',', 0.19507157818399515),
#  ('added', 0.1416384654932068),
#  ("'s", 0.11012275321283063),
#  ('but', 0.096675436568098),
#  ('says', 0.08836968511984952),
#  ('noted', 0.08819544901156108),
#  ('.', 0.08223991888292137)]

# %%
vcr=vectors(sentences,window=5)
vcr.nearest_neighbours('said')
# Out:
# [('said', 1.0),
#  ("''", 0.5290441758604836),
#  (',', 0.3955101788939153),
#  ('.', 0.2930806867989276),
#  ('economist', 0.24068712320692287),
#  ('he', 0.22958137259461872),
#  ('the', 0.20529199549183638),
#  ('minister', 0.19305798188873144),
#  ('at', 0.1889938259501839),
#  ('chief', 0.17971826978787217)]

# %%
vcr=vectors(sentences,window=10)
vcr.nearest_neighbours('said')
# Out:
# [('said', 1.0),
#  ("''", 0.5424119155291371),
#  (',', 0.4028636718802825),
#  ('.', 0.32495113212439214),
#  ('he', 0.2689308498941462),
#  ('the', 0.267067353236507),
#  ('of', 0.25247986636505915),
#  ('economist', 0.24782400139489105),
#  ('a', 0.2472763389925784),
#  ('in', 0.2411345856709793)]

# %%
vcr=vectors(sentences,window=25)
vcr.nearest_neighbours('said')
# Out:
# [('said', 1.0),
#  ("''", 0.5289694613477398),
#  ('``', 0.3969227947270833),
#  (',', 0.34138590962740445),
#  ('a', 0.3288429811353119),
#  ('it', 0.3282071673496143),
#  ('the', 0.3244342753502713),
#  ('he', 0.31633289775108114),
#  ('in', 0.3104919590499118),
#  ('of', 0.3070066691348281)]

# %%
winsize1.similarity("which","were")
# Out:
# 0.08177185265684372

# %%
winsize10.similarity("which","were")
# Out:
# 0.13540878782410715

# %%
winsize25.similarity("which","were")
# Out:
# 0.1528039243955428

# %%
winsize50.similarity("which","were")
# Out:
# 0.15466628602217478

# %%
winsize100.similarity("which","were")
# Out:
# 0.15484694578366287

# %% [markdown]
# 5.
# > I conducted a small investigation into the different window sizes. I did this by altering the context window size between 1 and 25 with the same word to see what the cosine similarity was for each word matching. It is clear and shown above, that as the context window increases so does the similarity score of each word. So to conclude, the correlation between semantic similarity and distribution similarity with different context window sizes is they both positively correlate together. If one increases so will the other, this is because words that are used and occur in the same contexts to each other typically follow similar meanings.

# %%
##This code will word count all of the markdown cells in the notebook saved at filepath
##Running it before providing any answers shows that the questions have a word count of 388

import io
from nbformat import current

filepath="/content/drive/My Drive/NLE Notebooks/assessment/NLEassignment2.ipynb"
question_count=568

with io.open(filepath, 'r', encoding='utf-8') as f:
    nb = current.read(f, 'json')

word_count = 0
for cell in nb.worksheets[0].cells:
    if cell.cell_type == "markdown":
        word_count += len(cell['source'].replace('#', '').lstrip().split(' '))
print("Submission length is {}".format(word_count-question_count))
# Out:
# /usr/local/lib/python3.6/dist-packages/nbformat/current.py:19: UserWarning: nbformat.current is deprecated.
#
# - use nbformat for read/write/validate public API
# - use nbformat.vX directly to composing notebooks of a particular version
#
#   """)
# Submission length is 515
